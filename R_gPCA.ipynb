# %%
library(gPCA)
data(caseDat)
batch<-caseDat$batch
data<-caseDat$data
out<-gPCA.batchdetect(x=data,batch=batch,center=FALSE,nperm=250)
out$delta ; out$p.val
# Out:
# [1] 0.5723599
# [1] "<0.001"

# %%
gDist(out)
# Out:
# Plot with title "Distribution of delta values from permutations
# (delta=0.572; p-value<0.004)"

# %%
CumulativeVarPlot(out,ug="unguided",col="blue")
# Out:
# plot without title

# %%
PCplot(out,ug="unguided",type="1v2")
# Out:
# plot without title

# %%
PCplot(out,ug="unguided",type="comp",npcs=4)
# Out:
# Plot with title ""
