# %%
from pyfasta import Fasta

# %%
import os
from pyfasta import Fasta
from time import strftime
import re

# %%
from __future__ import division
from __future__ import absolute_import
from __future__ import print_function
from builtins import range,object

# %%
import sys
if sys.version_info.major ==2:
	import cPickle as pickle
else:
	import pickle
	from sys import intern
import os
from pyfasta import Fasta
from time import strftime
import re

# %%
__author__ = 'Zhengtao Xiao'
__version__ = "1.2.15"

# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

def percentage_format(value,decimal=2):
	"""
	Format number as percentage
	"""
	formatStr = "{:." + str(decimal) + "%}"
	return formatStr.format(value)
	#return "{:.2%}".format(value)

def get_colors(NUM_COLORS):
	cm = plt.get_cmap('gist_rainbow')
	colors = []
	for i in range(NUM_COLORS):
		colors.append(cm(1.*i/NUM_COLORS))  # color will now be an RGBA tuple
	return colors

def pie(orderDict, outname):
	sizes = list(orderDict.values())
	total = sum(sizes)
	labels = []
	for i in orderDict.keys():
		perct = orderDict[i] / float(total)
		labels.append("%s: %i (%s)" % (i,int(orderDict[i]),percentage_format(perct,1)))

	colors = get_colors(len(labels))
	plt.figure(figsize=(8,6))
	patches, text = plt.pie(sizes, startangle=90,colors=colors)
	plt.legend(patches,labels,loc=4,bbox_to_anchor=(1, 0),fontsize=15)
	plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
	plt.tight_layout()
	plt.savefig(outname + "_ORFs_category.pdf")
	plt.close()

# %%
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import h5py
import os

def generate_colors(length,shiftn=0):
	"""
	generate r,b,g colors
	"""
	colors0 = ["red","blue","green"]
	colors1 = ["green","red","blue"]
	colors2 = ["blue","green","red"]
	rep_times = int(np.ceil(length/3))
	if shiftn == 0:
		colors = np.tile(colors0,rep_times)
	elif shiftn==1:
		colors = np.tile(colors1,rep_times)
	else:
		colors = np.tile(colors2,rep_times)
	return colors[:length]

def plot_ORF(ax,tpsites,orf_start,orf_stop,transcript_id,StartCodon):
	colors = generate_colors(tpsites.size,orf_start%3)
	ax.vlines(np.arange(tpsites.size),ymin=0,ymax=tpsites,colors=colors,linewidth=0.3)
	ax.tick_params(axis='x',which="both",top=False,direction='out',labelsize=15)
	ax.tick_params(axis='y',which="both",labelsize=15)
	ax.set_ylabel("P-site reads density",fontsize=18)
	ax.set_xlim((0,tpsites.size))
	ax.set_title(transcript_id+":"+str(orf_start)+"-"+str(orf_stop)+":"+StartCodon)

def plot_predicted(tpsites,orf_start,orf_stop,transcript_id,StartCodon,outname):
	fig=plt.figure(figsize=(8,4))
	## ax1
	ax1=fig.add_subplot(111)
	tpsites_orf=tpsites[int(orf_start)-1:orf_stop]
	colors = generate_colors(tpsites.size,orf_start%3)
	ax1.vlines(np.arange(tpsites_orf.size),ymin=0,ymax=tpsites_orf,colors=colors[int(orf_start)-1:orf_stop],linewidth=0.3)
	ax1.tick_params(axis='x',which="both",top=False,direction='out',labelsize=15)
	ax1.tick_params(axis='y',which="both",labelsize=15)
	ax1.set_ylabel("P-site reads density",fontsize=18)
	ax1.set_xlim((0,tpsites_orf.size))
	ax1.set_title(transcript_id+":"+str(orf_start)+"-"+str(orf_stop)+":"+StartCodon)
	plt.savefig(outname + ".pdf")


def plot_annotation(ax,tlength,start,stop,label,color):
	width = 0.15
	ax.set_xlim((0,tlength))
	ax.fill((start-1,stop,stop,start-1),
			(1+width/2,1+width/2,1-width/2,1-width/2),
			color=color,lw=0.5,zorder=20)
	ax.axhline(1,color="gray",lw=0.5)
	ax.set_frame_on(False)
	ax.xaxis.set_ticks_position("none")
	ax.yaxis.set_ticks_position("none")
	ax.set_xticks([])
	ax.set_yticks([1])
	ax.set_yticklabels([label],fontsize=18)
	ax.set_ylim((1-width/2,1+width/2))

def read_psites_array(filename,transcript_id):
	with h5py.File(filename,"r") as fin:
		k=np.array([i.decode("utf-8") if type(i)==bytes else i for i in fin["transcript_ids"][:]])
		idx = np.where(k == transcript_id)[0][0]
		v = fin["p_sites"][idx]
	return v

def plot_main(cds_start,cds_end,psites_array,orf_tstart,orf_tstop,transcript_id,StartCodon,outname):
	"""
	the main plot function
	"""
	plt.figure(figsize=(8,4))
	if cds_start is not None:
		gs = gridspec.GridSpec(3,1,height_ratios=[10,1,1],hspace=0.6,left=0.2,right=0.95)
	else:
		gs = gridspec.GridSpec(2,1,height_ratios=[11,1],hspace=0.6,left=0.2,right=0.95)

	ax1 = plt.subplot(gs[0])
	ax2 = plt.subplot(gs[1])
	plot_ORF(ax1,psites_array,orf_tstart,orf_tstop,transcript_id,StartCodon)
	plot_annotation(ax2,psites_array.size,orf_tstart,orf_tstop,"Predicted","#3994FF")

	if cds_start is not None:
		ax3 = plt.subplot(gs[2])
		plot_annotation(ax3,psites_array.size,cds_start,cds_end,"Annotated","#006DD5")
	# plt.tight_layout()
	plt.savefig(outname + ".pdf")

def main():
	from .parsing_opts import parsing_plot_orf_density
	from .loadconfig import LoadConfig
	args = parsing_plot_orf_density()
	transcripts_cds_file = os.path.join(args.annot_dir,"transcripts_cds.txt")
	cds_start = None
	cds_end = None
	with open(transcripts_cds_file) as fin:
		for line in fin:
			if line.startswith(args.transcript_id):
				_,s,e = line.strip().split("\t")
				cds_start = int(s)
				cds_end = int(e)
				break
	configIn = LoadConfig(args.config_file)
	samples = [i["samplename"] for i in configIn.configList]
	for i,s in enumerate(samples):
		if i == 0:
			psites_array = read_psites_array(s + "_psites.hd5",args.transcript_id)
		else:
			psites_array += read_psites_array(s + "_psites.hd5",args.transcript_id)
	if not args.outname:
		args.outname = "%s_%i_%i" % (args.transcript_id,args.orf_tstart,args.orf_tstop)
	if args.PlotAnnotatedORF.upper()=="YES":
		plot_main(cds_start,cds_end,psites_array,args.orf_tstart,args.orf_tstop,args.transcript_id,args.StartCodon,args.outname)
	elif args.PlotAnnotatedORF.upper() == 'NO':
		plot_predicted(psites_array,args.orf_tstart,args.orf_tstop,args.transcript_id,args.StartCodon,args.outname)
	else:
		raise IOError("Please reset your --plot-annotated-orf parameter: yes or no. default=yes")

# %%
from __future__ import division
from __future__ import absolute_import
from __future__ import print_function
# -*- coding:UTF-8 -*-
__author__ = 'Zhengtao Xiao'

import argparse
import os

def read_file(f):
	if not os.path.exists(f):
		raise  ValueError("Error, file %s not found!\n" % f)
	fList = []
	with open(f) as fin:
		for line in fin:
			if line.startswith("#") or line.strip() == "":
				continue
			fList.append(line.strip())
	return fList

def parsing_gtf_update():
	parser = argparse.ArgumentParser(
		description="This script is designed for preparing the appropriate GTF file from \
					 custom GTF file (or those not from ENSEMBL/GENCODE database)"
	)
	# parser.add_argument("-g","--add",dest="",required=True,type=str,
	#					 help="If add the gene information")
	# parser.add_argument("-t","",dest="",
	#					 help="if add the transcript information")
	parser.add_argument("gtfFile")
	args = parser.parse_args()
	return args

def parsing_transcript():
	parser = argparse.ArgumentParser(
		description="This script is designed for preparing transcripts annotation files."
	)
	parser.add_argument("-g","--gtf",dest="gtfFile",required=True,type=str,
						help='Default, suitable for GENCODE and ENSEMBL GTF file, \
							  please refer: https://en.wikipedia.org/wiki/GENCODE, \
							  or using GTFupdate command to update your GTF file.')
	parser.add_argument("-f","--fasta",dest="genomeFasta",required=True,type=str,
						help="The genome sequences file in fasta format.")
	parser.add_argument("-o","--out_dir",required=True,type=str,dest="out_dir",help="annotation directory name.")
	parser.add_argument('-V',"--version",action="version",version=__version__)
	args = parser.parse_args()

	if not os.path.exists(args.out_dir):
		try:
			os.mkdir(args.out_dir)
		except OSError as e:
			raise e

	if not os.path.exists(args.gtfFile):
		raise ValueError("Error, gtf file not found:%s.\n" % args.gtfFile)

	if not os.path.exists(args.genomeFasta):
		raise ValueError("Error, genomic fasta not found: %s\n" % args.genomeFata)

	return args
def parsing_metaplots():
	parser = argparse.ArgumentParser(
		description="""
		This script create aggregate plots of distances from the 5'end of reads to start or stop codons,
		which help determine the length range of the PRF reads that are most likely originated from the
		translating ribosomes and identify the P-site locations for each reads lengths.
		"""
	)
	parser.add_argument("-a","--annot_dir",dest="annot_dir",required=True,type=str,
						help="transcripts annotation directory, generated by prepare_transcripts.")
	group = parser.add_mutually_exclusive_group(required=True)
	group.add_argument("-r","--rpf_mapping_file",dest="rpf_mapping_file",required=False,type=str,
						help="ribo-seq BAM/SAM file aligned to the transcriptome.")
	group.add_argument("-i","--input_file",dest="rpf_mapping_file",required=False,type=read_file,
						help="the file list the ribo-seq BAM/SAM files aligned to the transcriptome.")
	parser.add_argument("-s","--stranded",dest="stranded",required=False,type=str,choices=["yes","reverse","no"],
						default="yes",help="whether the data is strand-specific, \
						reverse means reversed strand interpretation.(default: yes)")
	parser.add_argument("-m","--minimum-length",dest="minLength",required=False,type=int,default=24,
						help="minimum length of read to output, default 24")
	parser.add_argument("-M","--maximum-length",dest="maxLength",required=False,type=int,default=36,
						help="maximum length of read to output, default 36")
	parser.add_argument("-pv1","--pvalue1_cutoff",dest="pvalue1_cutoff",required=False,type=float,default=0.001,
						help="pvalue cutoff of frame0 > frame2 for automatically predicting P-site location, default 0.001")
	parser.add_argument("-pv2","--pvalue2_cutoff",dest="pvalue2_cutoff",required=False,type=float,default=0.001,
						help="pvalue cutoff of frame0 > frame2 for automatically predicting P-site location, default 0.001")
	parser.add_argument("-f0_percent","--frame0_percent",dest="frame0_percent",required=False,type=float,default=0.65,
						help="proportion threshold of the number of reads in frame0, defined by f0/(f0+f1+f2), default 0.65")
	parser.add_argument("-o","--outname",dest="outname",required=False,type=str,default="metaplots",
						help="name of output pdf file(default: metaplots)")
	parser.add_argument('-V',"--version",action="version",version=__version__)
	args = parser.parse_args()

	if not os.path.exists(args.annot_dir):
		raise ValueError("Error, the transcript annotation directory not found: {} \n \
						  pleas run prepare_transcripts.py first.".format(args.annot_dir))
	if args.minLength > args.maxLength:
		raise ValueError("minimum length must be <= maximum length (currently %d and %d, respectively)" % (args.minLength, args.maxLength))
	if args.minLength <= 0 or  args.maxLength <=0:
		raise ValueError("minimum length or maximum length must be larger than 0.")
	if type(args.rpf_mapping_file) is str:
		if not os.path.exists(args.rpf_mapping_file):
			raise  ValueError("Error, the rpf mapping file not found: %s\n" % args.rpf_mapping_file)
		args.rpf_mapping_file = [args.rpf_mapping_file]

	if args.stranded == "yes":
		args.stranded = True
	elif args.stranded == "reverse":
		args.stranded = False
	else:
		args.stranded = None
	args.pvalue1_cutoff = float(args.pvalue1_cutoff)
	args.pvalue2_cutoff = float(args.pvalue2_cutoff)
	args.frame0_percent = float(args.frame0_percent)

	return args

def parsing_ribo():
	parser = argparse.ArgumentParser(
		description="The main function designed for detecting ORF using ribosome-profiling data."
	)
	parser.add_argument("-a","--annot_dir",dest="annot_dir",required=True,type=str,
						help="transcripts annotation directory, generated by prepare_transcripts.")
	parser.add_argument("-c","--config_file",dest="config_file",required=True,type=str,
						help="list bam file and P-sites information in this file, \
						please refer to the example file in data folder.")
	# parser.add_argument("-n","--num-threads",dest="threads_num",default=1,required=False,
	#					 help="number of threads, optimal number is number of bam files.", type=int)
	parser.add_argument("-l","--longest-orf",dest="longest_orf",choices=["yes","no"],default="yes",required=False,
						help="Default: yes, the region from most distal AUG to stop was defined as an ORF. \
							  If set to no , the position of start codon will be automatically determined by program.", type=str)
	parser.add_argument("-s","--start_codon",default="ATG",type=str,dest="start_codon",
						help="The canonical start codon. default: ATG")
	parser.add_argument("-A","--alt_start_codons",default="",type=str,dest="alternative_start_codons",
						help="The alternative start codon, such as CTG,GTG, default: None. Multiple codons should be separated by comma.")
	parser.add_argument("-S","--stop_codon",default="TAA,TAG,TGA",type=str,dest="stop_codon",
						help="Stop codon, default: TAA,TAG,TGA")
	parser.add_argument("-t","--transl_table",default=1,dest="transl_table",type=int,
						help="ORF translation table(Default: 1). Assign the correct genetic code based on your organism, \
						[please refer: https://www.ncbi.nlm.nih.gov/Taxonomy/Utils/wprintgc.cgi]")
	parser.add_argument("-m","--min-AA-length",dest="min_AA_length",default="5",required=False,
						help="The minimal length of predicted peptides,default 5", type=int)
	parser.add_argument("--dependence_test", dest="dependence_test", required=False, type=str, default="none",
						choices=["none", "mic", "pcc"],
						help="the method for measuring the dependence between frame1 and frame2. \n \
							This test could help determine whether the combined p-values should be ajusted to account for the dependence between two test (i.e. F0 vs F1 and F0 vs F2). \n \
							mic: Maximal Information Coefficient; pcc: Pearson Correlation Coefficient.")
	parser.add_argument("--stouffer_adj", dest="stouffer_adj", required=False, type=str, default="none",
						choices=["none","nyholt", "liji", "gao", "galwey"],
						help="the method for adjustment the cominbed p-values to account for the dependence between two tests (i.e. F0 vs F1 and F0 vs F2). \n \
							see details at: https://search.r-project.org/CRAN/refmans/poolr/html/stouffer.html")
	parser.add_argument("-p","--pval-cutoff",dest="pval_cutoff",default=0.05,required=False,
						help="P-value cutoff for ORF filtering, default 0.05", type=float)
	parser.add_argument("--pval_adj", dest="pval_adj", required=False, type=str, default="fdr_bh",
						choices=["fdr_bh","bonferroni","sidak","holm-sidak","holm","simes-hochberg","hommel","fdr_by","fdr_tsbh","fdr_tsbky"],
						help="the method used to correct p-values for multiple testing. default: Benjamini/Hochberg method. \n \
							see details at: https://www.statsmodels.org/devel/generated/statsmodels.stats.multitest.multipletests.html#statsmodels.stats.multitest.multipletests")
	# parser.add_argument("-P","--parallel_num",dest="parallel_num",default=1,required=False,
	#					 help="the number of threads to read the alignment file(s), \
	#					 the optimal value is the number of alignment files, default=1",type=int)
	parser.add_argument("-g","--output-gtf",dest="output_gtf",action='store_true',default=False,required=False,
						help="output the gtf file of predicted ORFs")
	parser.add_argument("-b","--output-bed",dest="output_bed",action='store_true',default=False,required=False,
						help="output the bed file of predicted ORFs")
	parser.add_argument("-o","--output-name",dest="output_name",default="final_result",required=False,
						help="output file name, default: final_result", type=str)
	parser.add_argument('-V',"--version",action="version",version=__version__)
	args = parser.parse_args()

	if not os.path.exists(args.annot_dir):
		raise ValueError("Error, the transcript annotation directory not found: {} \n \
					 pls run prepare_transcripts.py first. ".format(args.annot_dir))

	return args

def parsing_plot_orf_density():
	parser = argparse.ArgumentParser(
		description="This script is designed for plot the P-site profile of specified ORF."
	)
	parser.add_argument("-a","--annot_dir",dest="annot_dir",required=True,type=str,
						help="transcripts annotation directory, generated by prepare_transcripts.")
	parser.add_argument("-c","--config_file",dest="config_file",required=True,
						help="defile bam file information in this file, \
						please refer to the example file in data folder.",type=str)
	parser.add_argument("-t","--transcript_id",dest="transcript_id",required=True,type=str,
						help="the transcript id")
	parser.add_argument("-s","--orf_tstart",dest="orf_tstart",required=True,type=int,
						help="transcript-level coordinates of start of ORF (orf_tstart)")
	parser.add_argument("-e","--orf_tstop",dest="orf_tstop",required=True,type=int,
						help="transcript-level coordinates of end of ORF (orf_tstop)")
	parser.add_argument("-o","--outname",dest="outname",required=False,type=str,default="",
						help="output file name,default is transcriptid_tstart_tstop.pdf")
	parser.add_argument("--start-codon",dest="StartCodon",required=True,type=str,
						help="start codon of predicted ORFs")
	parser.add_argument("--plot-annotated-orf",dest="PlotAnnotatedORF",required=False,type=str,default="yes",
						help="plot the annotated orf (yes) or not (no).")
	parser.add_argument('-V',"--version",action="version",version=__version__)
	args = parser.parse_args()

	args.orf_tstart = args.orf_tstart -1 # change to 0 based
	if not os.path.exists(args.annot_dir):
		raise ValueError("Error, the transcript annotation directory not found: {} \n \
					 pls run prepare_transcripts.py first. ".format(args.annot_dir))
	return args

def parsing_ORF_count():
	parser = argparse.ArgumentParser(
		description="This script is designed for calculating the number of reads mapping to ORF with the alignment files \
		in SAM/BAM format (aligned to genome) and a feature file in GTF format"
	)
	parser.add_argument("-s","--stranded",dest="stranded",required=False,type=str,choices=["yes","reverse","no"],
						default="yes",help="whether the data is strand-specific, \
						reverse means reversed strand interpretation. (default: yes)")
	parser.add_argument("-a","--minaqual",dest="min_quality",required=False,type=int,
						default=10,help="skip all reads with alignment quality lower than the given minimum value (default:10)")
	parser.add_argument("-c","--count_mode",dest="count_mode",required=False,type=str,choices=["union","intersection-strict"],
						default="intersection-strict",help="mode to handle reads overlapping more than one ORF (choices:\
						union,intersection-strict;default: intersection-strict)")
	parser.add_argument("-g","--gtf",dest="gtf_file",required=False,type=str,default="final_result_collapsed.gtf",
						help="ORF gtf file generated by RiboCode, default:final_result")
	parser.add_argument("-r","--rpf_mapping_file",dest="rpf_mapping_file",required=True,type=str,
						help="ribo-seq BAM/SAM file aligned to the genome, multiple files should be separated with \",\"")
	parser.add_argument("-f","--first_exclude_codons",dest="first_exclude_codons",required=False,type=int,default=15,
						help="excluding the reads aligned to the first few codons of the ORF, default:15")
	parser.add_argument("-l","--last_exclude_codons",dest="last_exclude_codons",required=False,type=int,default=5,
						help="excluding the reads aligned to the last few codons of the ORF, default:5")
	parser.add_argument("-e","--exclude_min_ORF",dest="exclude_min_ORF",required=False,type=int,default=100,
						help="the minimal length(nt) of ORF for excluding the reads aligned to first and last few codons, default:100")
	parser.add_argument("-m","--min_read",dest="min_read",required=False,type=int,default=26,
						help="minimal read length for the counting of RPF,default:26")
	parser.add_argument("-M","--max_read",dest="max_read",required=False,type=int,default=34,
						help="maximal read length for the counting of RPF,default:34")
	# parser.add_argument("-p","--parallel_num",dest="parallel_num",required=False,type=int,default=1,
	#					 help="the number of threads to read the alignment file(s), \
	#					 the optimal value is the number of alignment files, default=1")
	parser.add_argument("-o","--output",dest="output_file",required=False,type=str,
						default="-",help="write out all ORF counts into a file, default is to write to standard output")
	parser.add_argument('-V',"--version",action="version",version=__version__)
	args = parser.parse_args()

	if not os.path.exists(args.gtf_file):
		raise ValueError("Error, the gtf file not found: {}".format(args.gtf_file))
	if args.first_exclude_codons * 3 + args.last_exclude_codons * 3 >= args.exclude_min_ORF:
		raise ValueError("Error, the exclude_min_ORF is too small: %i" % args.exclude_min_ORF)
	if "," in args.rpf_mapping_file:
		rpf_mapping_files = [i.strip() for i in args.rpf_mapping_file.split(",")]
		args.rpf_mapping_file = rpf_mapping_files
	else:
		args.rpf_mapping_file = [args.rpf_mapping_file]
	# if args.parallel_num > len(args.rpf_mapping_file):
	# 	args.parallel_num = len(args.rpf_mapping_file)
	return args

def parsing_ribo_onestep():
	parser = argparse.ArgumentParser(
		description="The function contains the steps to prepare a reference genome, to determinate the P-site locations" +
					" and to detect ORFs. It automatically creates some of the output files."

	)
	parser.add_argument("-g","--gtf",dest="gtfFile",required=True,type=str,
						help='Default, suitable for GENCODE and ENSEMBL GTF file, \
							  please refer: https://en.wikipedia.org/wiki/GENCODE')
	parser.add_argument("-f","--fasta",dest="genomeFasta",required=True,type=str,
						help="The genome sequences file in fasta format.")
	group = parser.add_mutually_exclusive_group(required=True)
	group.add_argument("-r","--rpf_mapping_file",dest="rpf_mapping_file",required=False,type=str,
						help="ribo-seq BAM/SAM file aligned to the transcriptome.")
	group.add_argument("-i","--input_file",dest="rpf_mapping_file",required=False,type=read_file,
						help="the file list the ribo-seq BAM/SAM files aligned to the transcriptome.")
	parser.add_argument("-stranded","--stranded",dest="stranded",required=False,type=str,choices=["yes","reverse","no"],
						default="yes",help="whether the data is strand-specific, \
						reverse means reversed strand interpretation.(default: yes)")
	parser.add_argument("-m","--minimum-length",dest="minLength",required=False,type=int,default=24,
						help="minimum read length for metaplots analysis, default 24")
	parser.add_argument("-M","--maximum-length",dest="maxLength",required=False,type=int,default=36,
						help="maximum read length for metaplots analysis, default 36")
	parser.add_argument("-f0_percent","--frame0_percent",dest="frame0_percent",required=False,type=float,default=0.65,
						help="proportion threshold of reads in frame0. For automatically predicting P-site location, default 0.65")
	parser.add_argument("-l","--longest-orf",dest="longest_orf",choices=["yes","no"],default="yes",required=False,
						help="Default: yes, the region from most distal AUG to stop was defined as an ORF. \
							  If set to no , the position of start codon will be automatically determined by program.", type=str)
	parser.add_argument("-p","--pval-cutoff",dest="pval_cutoff",default=0.05,required=False,
						help="P-value cutoff for ORF filtering, default 0.05", type=float)
	parser.add_argument("-s","--start_codon",default="ATG",type=str,dest="start_codon",
						help="The canonical start codon. default: ATG")
	parser.add_argument("-A","--alt_start_codons",default="",type=str,dest="alternative_start_codons",
						help="The alternative start codon, such as CTG,GTG, default: None. Multiple codons should be separated by comma.")
	parser.add_argument("-S","--stop_codon",default="TAA,TAG,TGA",type=str,dest="stop_codon",
						help="Stop codon, default: TAA,TAG,TGA")
	parser.add_argument("-t","--transl_table",default=1,dest="transl_table",type=int,
						help="ORF translation table(Default: 1). Assign the correct genetic code based on your organism, \
						[please refer: https://www.ncbi.nlm.nih.gov/Taxonomy/Utils/wprintgc.cgi]")
	parser.add_argument("-mA","--min-AA-length",dest="min_AA_length",default="20",required=False,
						help="The minimal length of predicted peptides,default 20", type=int)
	parser.add_argument("--dependence_test", dest="dependence_test", required=False, type=str, default="none",
						choices=["none", "mic", "pcc"],
						help="the method for measuring the dependence between frame1 and frame2. \n \
							This test could help determine whether the combined p-values should be ajusted to account for the dependence between two test (i.e. F0 vs F1 and F0 vs F2). \n \
							mic: Maximal Information Coefficient; pcc: Pearson Correlation Coefficient.")
	parser.add_argument("--stouffer_adj", dest="stouffer_adj", required=False, type=str, default="none",
						choices=["none","nyholt", "liji", "gao", "galwey"],
						help="the method for adjustment the cominbed p-values to account for the dependence between two tests (i.e. F0 vs F1 and F0 vs F2). \n \
							see details at: https://search.r-project.org/CRAN/refmans/poolr/html/stouffer.html")
	parser.add_argument("--pval_adj", dest="pval_adj", required=False, type=str, default="fdr_bh",
						choices=["fdr_bh","bonferroni","sidak","holm-sidak","holm","simes-hochberg","hommel","fdr_by","fdr_tsbh","fdr_tsbky"],
						help="the method used to correct p-values for multiple testing. default: Benjamini/Hochberg method. \n \
							see details at: https://www.statsmodels.org/devel/generated/statsmodels.stats.multitest.multipletests.html#statsmodels.stats.multitest.multipletests")
	# parser.add_argument("-P","--parallel_num",dest="parallel_num",default=1,required=False,
	#					 help="the number of threads to read the alignment file(s), \
	#					 the optimal value is the number of alignment files, default=1",type=int)
	parser.add_argument("-o","--output-name",dest="output_name",default="final_result",required=False,
						help="output file name, default: final_result", type=str)
	parser.add_argument("-outgtf","--output-gtf",dest="output_gtf",action='store_true',default=False,required=False,
						help="output the gtf file of predicted ORFs")
	parser.add_argument("-outbed","--output-bed",dest="output_bed",action='store_true',default=False,required=False,
						help="output the bed file of predicted ORFs")
	parser.add_argument('-V',"--version",action="version",version=__version__)
	args = parser.parse_args()
	if type(args.rpf_mapping_file) is str:
		if not os.path.exists(args.rpf_mapping_file):
			raise  ValueError("Error, the rpf mapping file not found: %s\n" % args.rpf_mapping_file)
		args.rpf_mapping_file = [args.rpf_mapping_file]
	if args.stranded == "yes":
		args.stranded = True
	elif args.stranded == "reverse":
		args.stranded = False
	else:
		args.stranded = None
	if args.minLength > args.maxLength:
		raise ValueError("minimum length must be <= maximum length (currently %d and %d, respectively)" % (args.minLength, args.maxLength))
	if args.minLength <= 0 or  args.maxLength <=0:
		raise ValueError("minimum length or maximum length must be larger than 0.")
	args.frame0_percent = float(args.frame0_percent)

	return args

# %%
from Bio.Seq import translate
from sys import stderr
def translation(seq,table=1,cds=True):
	"""
	translate the DNA to protein sequence using the translation table
	table = 1, is the standard table, ref: https://www.ncbi.nlm.nih.gov/Taxonomy/Utils/wprintgc.cgi
	"""
	if len(seq) % 3 != 0:
		stderr.write("Warning: sequence is not divisible by 3")
		seq = seq[:-(len(seq) % 3)]
	return translate(seq,table,cds=cds)

# %%
import re

def searchCodon(seq,START_CODON,ALTERNATIVE_START_CODON_LIST,STOP_CODON_LIST):
	"""
	search all start codon and stop codons for each frame
	:param seq:
	:return: start_codon_dict, stop_codon_dict, the key is frame.
	"""

	seq = seq.upper()

	start_regx = re.compile('|'.join(START_CODON))
	stop_regx = re.compile('|'.join(STOP_CODON_LIST))

	start_idx = [m.start(0) for m in re.finditer(start_regx,seq)]
	stop_idx = [m.start(0) for m in re.finditer(stop_regx,seq)]
	if ALTERNATIVE_START_CODON_LIST:
		alt_start_regx = re.compile('|'.join(ALTERNATIVE_START_CODON_LIST))
		alt_start_idx = [m.start(0) for m in re.finditer(alt_start_regx,seq)]
	else:
		alt_start_idx = False
	return start_idx,stop_idx,alt_start_idx

def orf_find(start_idx,stop_idx,alt_start_idx,MIN_AA_LENGTH):
	"""
	extract ORFs
	"""
	commonstop_dict = {}
	for f in (0,1,2):
		inframe_stops = [x for x in stop_idx if x%3==f]
		inframe_starts = [x for x in start_idx if x%3==f]
		if alt_start_idx:
			inframe_alt_starts = [x for x in alt_start_idx if x%3==f]
		else:
			inframe_alt_starts = None

		last_stop = -1
		for j in inframe_stops:
			tmp_starts = []
			alt_flag = 1
			if inframe_starts:
				for i in inframe_starts:
					if i < j and i > last_stop and (j-i) >= MIN_AA_LENGTH*3:
						alt_flag = 0
						tmp_starts.append(i)
			if alt_flag and inframe_alt_starts:
				for i in inframe_alt_starts:
					if i < j and i > last_stop and (j-i) >= MIN_AA_LENGTH*3:
						tmp_starts.append(i)
			last_stop = j
			if tmp_starts:
				commonstop_dict[j] = tmp_starts
	return commonstop_dict

def orf_finder(seq,START_CODON,ALTERNATIVE_START_CODON_LIST,STOP_CODON_LIST,MIN_AA_LENGTH):
	start_idx,stop_idx,alt_start_idx = searchCodon(seq,START_CODON,ALTERNATIVE_START_CODON_LIST,STOP_CODON_LIST)
	orf_dict = orf_find(start_idx,stop_idx,alt_start_idx,MIN_AA_LENGTH)
	return orf_dict

# %%
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import h5py
import os

def generate_colors(length,shiftn=0):
	"""
	generate r,b,g colors
	"""
	colors0 = ["red","blue","green"]
	colors1 = ["green","red","blue"]
	colors2 = ["blue","green","red"]
	rep_times = int(np.ceil(length/3))
	if shiftn == 0:
		colors = np.tile(colors0,rep_times)
	elif shiftn==1:
		colors = np.tile(colors1,rep_times)
	else:
		colors = np.tile(colors2,rep_times)
	return colors[:length]

def plot_ORF(ax,tpsites,orf_start,orf_stop,transcript_id,StartCodon):
	colors = generate_colors(tpsites.size,orf_start%3)
	ax.vlines(np.arange(tpsites.size),ymin=0,ymax=tpsites,colors=colors,linewidth=0.3)
	ax.tick_params(axis='x',which="both",top=False,direction='out',labelsize=15)
	ax.tick_params(axis='y',which="both",labelsize=15)
	ax.set_ylabel("P-site reads density",fontsize=18)
	ax.set_xlim((0,tpsites.size))
	ax.set_title(transcript_id+":"+str(orf_start)+"-"+str(orf_stop)+":"+StartCodon)

def plot_predicted(tpsites,orf_start,orf_stop,transcript_id,StartCodon,outname):
	fig=plt.figure(figsize=(8,4))
	## ax1
	ax1=fig.add_subplot(111)
	tpsites_orf=tpsites[int(orf_start)-1:orf_stop]
	colors = generate_colors(tpsites.size,orf_start%3)
	ax1.vlines(np.arange(tpsites_orf.size),ymin=0,ymax=tpsites_orf,colors=colors[int(orf_start)-1:orf_stop],linewidth=0.3)
	ax1.tick_params(axis='x',which="both",top=False,direction='out',labelsize=15)
	ax1.tick_params(axis='y',which="both",labelsize=15)
	ax1.set_ylabel("P-site reads density",fontsize=18)
	ax1.set_xlim((0,tpsites_orf.size))
	ax1.set_title(transcript_id+":"+str(orf_start)+"-"+str(orf_stop)+":"+StartCodon)
	plt.savefig(outname + ".pdf")


def plot_annotation(ax,tlength,start,stop,label,color):
	width = 0.15
	ax.set_xlim((0,tlength))
	ax.fill((start-1,stop,stop,start-1),
			(1+width/2,1+width/2,1-width/2,1-width/2),
			color=color,lw=0.5,zorder=20)
	ax.axhline(1,color="gray",lw=0.5)
	ax.set_frame_on(False)
	ax.xaxis.set_ticks_position("none")
	ax.yaxis.set_ticks_position("none")
	ax.set_xticks([])
	ax.set_yticks([1])
	ax.set_yticklabels([label],fontsize=18)
	ax.set_ylim((1-width/2,1+width/2))

def read_psites_array(filename,transcript_id):
	with h5py.File(filename,"r") as fin:
		k=np.array([i.decode("utf-8") if type(i)==bytes else i for i in fin["transcript_ids"][:]])
		idx = np.where(k == transcript_id)[0][0]
		v = fin["p_sites"][idx]
	return v

def plot_main(cds_start,cds_end,psites_array,orf_tstart,orf_tstop,transcript_id,StartCodon,outname):
	"""
	the main plot function
	"""
	plt.figure(figsize=(8,4))
	if cds_start is not None:
		gs = gridspec.GridSpec(3,1,height_ratios=[10,1,1],hspace=0.6,left=0.2,right=0.95)
	else:
		gs = gridspec.GridSpec(2,1,height_ratios=[11,1],hspace=0.6,left=0.2,right=0.95)

	ax1 = plt.subplot(gs[0])
	ax2 = plt.subplot(gs[1])
	plot_ORF(ax1,psites_array,orf_tstart,orf_tstop,transcript_id,StartCodon)
	plot_annotation(ax2,psites_array.size,orf_tstart,orf_tstop,"Predicted","#3994FF")

	if cds_start is not None:
		ax3 = plt.subplot(gs[2])
		plot_annotation(ax3,psites_array.size,cds_start,cds_end,"Annotated","#006DD5")
	# plt.tight_layout()
	plt.savefig(outname + ".pdf")

def main():
	from .parsing_opts import parsing_plot_orf_density
	from .loadconfig import LoadConfig
	args = parsing_plot_orf_density()
	transcripts_cds_file = os.path.join(args.annot_dir,"transcripts_cds.txt")
	cds_start = None
	cds_end = None
	with open(transcripts_cds_file) as fin:
		for line in fin:
			if line.startswith(args.transcript_id):
				_,s,e = line.strip().split("\t")
				cds_start = int(s)
				cds_end = int(e)
				break
	configIn = LoadConfig(args.config_file)
	samples = [i["samplename"] for i in configIn.configList]
	for i,s in enumerate(samples):
		if i == 0:
			psites_array = read_psites_array(s + "_psites.hd5",args.transcript_id)
		else:
			psites_array += read_psites_array(s + "_psites.hd5",args.transcript_id)
	if not args.outname:
		args.outname = "%s_%i_%i" % (args.transcript_id,args.orf_tstart,args.orf_tstop)
	if args.PlotAnnotatedORF.upper()=="YES":
		plot_main(cds_start,cds_end,psites_array,args.orf_tstart,args.orf_tstop,args.transcript_id,args.StartCodon,args.outname)
	elif args.PlotAnnotatedORF.upper() == 'NO':
		plot_predicted(psites_array,args.orf_tstart,args.orf_tstop,args.transcript_id,args.StartCodon,args.outname)
	else:
		raise IOError("Please reset your --plot-annotated-orf parameter: yes or no. default=yes")

# %%
from pyfasta import DuplicateHeaderException
# ?DuplicateHeaderException
# Out:
# Init signature: DuplicateHeaderException(header)
# Docstring:      Common base class for all non-exit exceptions.
# File:           ~/.local/lib/python3.8/site-packages/pyfasta/fasta.py
# Type:           type
# Subclasses:

# %%
from __future__ import division
from __future__ import absolute_import
from __future__ import print_function
from builtins import range,object
# -*- coding:UTF-8 -*-
"""
preparing the transcripts annotation files.
"""
import sys
if sys.version_info.major ==2:
	import cPickle as pickle
else:
	import pickle
	from sys import intern
import os
from pyfasta import Fasta
from time import strftime
import re

class ParsingError(Exception):
	pass

class Interval(object):
	""" basic interval """
	def __init__(self,start,end,strand):
		if end < start:
			raise ValueError('Error: end smaller than start !')

		self.start = start
		self.end = end
		self.strand = strand
		if strand == "+":
			self.start_d = start
			self.end_d = end
		elif strand == "-":
			self.start_d = end - 1
			self.end_d = start - 1
		else:
			raise ValueError('Error: strand is neither "+" nor "-" !')
		self.length = end - start

	def contain(self,start,end):
		if end < start:
			raise ValueError('Error: end smaller than start !')
		if self.start <= start and self.end >= end:
			return True
		else:
			return False

	def contain_iv(self,iv):
		return self.contain(iv.start,iv.end)

	def is_overlapped_with(self, iv):
		if self.start <= iv.start <= self.end or self.start <= iv.end <= self.end:
			return True
		else:
			return False

	def __str__(self):
		return "iv:%i-%i" % (self.start,self.end)

	__repr__ = __str__

def Interval_from_directional(start_d,end_d,strand="-"):
	if strand == "-":
		return Interval(end_d+1,start_d+1,"-")
	else:
		return Interval(start_d,end_d,"+")

def parsing_attr(attr_string):
	attr_dict = {}
	attr_split = re.findall(r'.*? ".*?";', attr_string)
	for i in attr_split:
		if i:
			k,v = i.strip().split(" ",1)
			k = intern(k)
			if v.endswith(";"): v = v[:-1]
			v = intern(v.strip('"'))
			if k == "tag":
				attr_dict.setdefault(k,[]).append(v)
			else:
				attr_dict[k] = v
	return attr_dict

def parsing_line(line):
	"""
        # GTF columns:
        # 1) chrom: str ("1", "X", "chrX", etc...)
        # 2) source : str (not used)
        # 3) feature : str ("gene", "transcript", &c)
        # 4) start : int
        # 5) end : int
        # 6) score : float or "." (not used)
        # 7) strand : "+", "-", or "."
        # 8) frame : 0, 1, 2 or "." (not used)
        # 9) attribute : key-value pairs separated by semicolons
	"""
	chrom,source,feature,start,end,score,strand,frame,attr = line.strip().split("\t",8)
	#convert to 0-based.
	iv = Interval(int(start) - 1, int(end), strand)
	field_dict = {"chrom": intern(chrom),"source":source,"feature": intern(feature),"iv":iv,"attr":parsing_attr(attr)}
	return field_dict

class Gene(object):
	""" Gene object """

	def __init__(self,field_dict):
		self.chrom = field_dict["chrom"]
		self.genomic_iv = field_dict["iv"]
		self.attr = field_dict["attr"]
		self.gene_id = self.attr["gene_id"]
		self.gene_name = self.attr.get("gene_name",self.attr.get("gene_id",None))
		self.gene_type = self.attr.get("gene_type",self.attr.get("gene_biotype",None))
		self.transcripts = []
		self.principal_transcripts = []

	def __str__(self):
		return "GeneID:%s;GeneName:%s;GeneType:%s" % (self.gene_id,self.gene_name,self.gene_type)

	__repr__ = __str__

class Transcript(object):
	""" Transcript object """

	def __init__(self,field_dict):
		self.chrom = field_dict["chrom"]
		self.genomic_iv = field_dict["iv"]
		self.attr = field_dict["attr"]
		self.gene_id = self.attr["gene_id"]
		self.gene_name = self.attr.get("gene_name",self.attr.get("gene_id",None))
		self.transcript_type = self.attr.get("transcript_type",self.attr.get("transcript_biotype",None))
		self.transcript_id = self.attr["transcript_id"]
		self.genomic_exons = []
		self.genomic_cds = []
		self.genomic_startcodon = []
		self.genomic_stopcodon = []
		self.length = 0

		self.cds = None
		self.startcodon = None
		self.stopcodon = None

	def add_feature(self,field_dict):
		feature = field_dict["feature"]
		iv = field_dict["iv"]
		if feature == "exon":
			self.genomic_exons.append(iv)
			self.length += iv.length
		elif feature == "CDS":
			self.genomic_cds.append(iv)
		elif feature == "start_codon":
			self.genomic_startcodon.append(iv)
		elif feature == "stop_codon":
			self.genomic_stopcodon.append(iv)
		else:
			raise ValueError("Error: the feature is not recognized: %s" % feature)

	def __str__(self):
		return "TranscriptID:%s;TranscriptType:%s" % (self.transcript_id,self.transcript_type)

	__repr__ = __str__

def readGTF(filename):
	if not os.path.exists(filename):
		raise IOError("\tGTF file does not exist: %s" % filename)
	sys.stdout.write("\tReading the GTF file: %s .......\n" % filename)
	gene_dict = {}
	transcript_dict = {}
	with open(filename) as fin:
		for i,line in enumerate(fin):
			if line[0] == "#" or (not line.strip()):
				continue
			field_dict = parsing_line(line)
			if field_dict["feature"] == "gene":
				gobj = Gene(field_dict)
				gene_dict[gobj.gene_id] = gobj
			elif field_dict["feature"] == "transcript":
				tobj = Transcript(field_dict)
				transcript_dict[tobj.transcript_id] = tobj
			elif field_dict["feature"] in ["exon","CDS","start_codon","stop_codon"]:
				tid = field_dict["attr"]["transcript_id"]
				try:
					transcript_dict[tid].add_feature(field_dict)
				except KeyError:
					raise ParsingError("Error in line %i. The annotation in GTF file should be three-level hierarchy of \
					                    gene => transcript => exon (or CDS)" % i)
			else:
				pass
	return gene_dict,transcript_dict

def get_chrom(name):
	if " " in name:
		return name.split()[0]
	elif "|" in name:
		return name.split("|")
	else:
		return name

class GenomeSeq(object):
	""" genomic sequence"""

	def __init__(self,filename):
		self.filename = filename
		self.fh = Fasta(filename, key_fn = get_chrom)
	def get_seq(self,chrom,start=0,end=False,strand="+"):
		if end is False:
			end = len(self.fh[chrom])
		return self.fh.sequence({"chr":chrom, "start":start, "stop": end, "strand":strand}, one_based=False)


def genomic_iv_transform(genomic_exons_sorted, genomic_ivs_sorted):
	"""
	transform the genomic interval (of cds, start and stop codons) to inner coordinate in transcript,
	transcript_exons must be sorted
	return 0-based iv
	"""

	length = 0
	innerIV = []
	for i in genomic_exons_sorted:
		for j in genomic_ivs_sorted:
			if i.contain_iv(j):
				start = length + abs(j.start_d - i.start_d)
				end = start + (j.end - j.start)
				if innerIV and start == innerIV[-1].end:
					innerIV[-1] = Interval(innerIV[-1].start, end, "+")
				else:
					innerIV.append(Interval(start,end,"+"))
		length += i.end - i.start
	if len(innerIV) == 0:
		raise ValueError("\tCan't transform the genomic interval, please check!")
	return innerIV

def transcript_pos_transform(tobj, transcript_pos):
	"""
	transform the transcript position to genomic position
	0-based
	if strand is "-", return position of strand.
	"""
	length = 0
	strand = tobj.genomic_iv.strand
	genomic_pos = -1
	for i in tobj.genomic_exons:
		if transcript_pos < length + i.length:
			if strand == "+":
				genomic_pos = transcript_pos - length + i.start
			else:
				genomic_pos = i.start_d - (transcript_pos - length)
			break
		length += i.length
	return genomic_pos

def transcript_iv_transform(tobj, transcript_iv):
	"""
	transform the transcript interval to genomic interval, zero-based.
	"""
	strand = tobj.genomic_iv.strand
	genomic_start = transcript_pos_transform(tobj,transcript_iv.start)
	genomic_end = transcript_pos_transform(tobj,transcript_iv.end-1)
	if strand == "+":
		genomic_end += 1
	else:
		genomic_end -= 1
	exons_bound = [genomic_start]


	for i in tobj.genomic_exons:
		if strand == "+":
			if genomic_start < i.start < genomic_end:
				exons_bound.append(i.start)
			if genomic_start < i.end < genomic_end:
				exons_bound.append(i.end)
		else:
			if genomic_end < i.start_d < genomic_start:
				exons_bound.append(i.start_d)
			if genomic_end < i.end_d < genomic_start:
				exons_bound.append(i.end_d)

	exons_bound.append(genomic_end)
	if len(exons_bound) % 2 != 0:
		print("error when transform the transcript interval to genomic!")
	exons_ivs = []
	for i in range(0,len(exons_bound),2):
		exons_ivs.append(Interval_from_directional(exons_bound[i],exons_bound[i+1],strand))

	return exons_ivs

def load_transcripts_pickle(pickle_file):
	if os.path.exists(pickle_file):
		sys.stdout.write("\tLoading transcripts.pickle ...\n")
		with open(pickle_file,"rb") as fin:
			gene_dict, transcript_dict = pickle.load(fin)
	else:
		raise IOError("\tError, %s file not found\n" % pickle_file)

	return gene_dict,transcript_dict

def processTranscripts(genomeFasta,gtfFile,out_dir):
	"""
	transform the genomic position into the transcript position
	"""
	pickle_file = os.path.join(out_dir,"transcripts.pickle")
	if os.path.exists(pickle_file):
		gene_dict, transcript_dict = load_transcripts_pickle(pickle_file)
		return gene_dict, transcript_dict
	else:
		gene_dict,transcript_dict = readGTF(gtfFile)
		if not os.path.exists(genomeFasta):
			raise IOError("\tError, the genomic fasta file not found: %s" % genomeFasta)
		genomic_seq = GenomeSeq(genomeFasta)
		transcript_seq_file = open(os.path.join(out_dir,"transcripts_sequence.fa"),"w") #title: transcriptid length
		transcript_cds_file = open(os.path.join(out_dir,"transcripts_cds.txt"),"w") # tid, cds_start, cds_end

		sys.stderr.write("\tProcess the transcripts ....\n")
		for tobj in transcript_dict.values():
			# store the transcript id in gene object
			if tobj.transcript_id not in gene_dict[tobj.gene_id].transcripts:
				gene_dict[tobj.gene_id].transcripts.append(tobj.transcript_id)
				if "appris_principal_1" in tobj.attr.get("tag",[]) or "appris_principal" in tobj.attr.get("tag", []):
					gene_dict[tobj.gene_id].principal_transcripts.append(tobj.transcript_id)
			# sort the exons,cds,startcodon,stopcodon according their position on genomic
			if tobj.genomic_iv.strand == "+":
				sorted_reverse = False
			else:
				sorted_reverse = True

			tobj.genomic_exons.sort(key=lambda x: x.start, reverse=sorted_reverse)
			# convert the CDS genomic coordination into transcript coordination
			if tobj.genomic_cds:
				tobj.genomic_cds.sort(key=lambda x: x.start, reverse=sorted_reverse)
				tobj.cds = genomic_iv_transform(tobj.genomic_exons, tobj.genomic_cds)
				if len(tobj.cds) > 1:
					sys.stderr.write("Warning: the CDS is discontinuous," +
					                  "only first region is used, %s\n" % tobj.transcript_id)
				tobj.cds = tobj.cds[0]
				transcript_cds_file.write("%s\t%i\t%i\n" % (tobj.transcript_id,tobj.cds.start +1,tobj.cds.end + 3))

			# start and stop codon
			if tobj.genomic_startcodon:
				tobj.genomic_startcodon.sort(key=lambda x: x.start, reverse=sorted_reverse)
				tobj.startcodon = genomic_iv_transform(tobj.genomic_exons,tobj.genomic_startcodon)
				if len(tobj.startcodon) >1:
					sys.stderr.write("Warning: the start codon is discontinuous," +
					                "only first region is used, %s\n" % tobj.transcript_id)
				tobj.startcodon = tobj.startcodon[0]
			elif tobj.cds:
				tobj.startcodon = Interval(tobj.cds.start, tobj.cds.start + 3, "+")
			else:
				pass

			if tobj.genomic_stopcodon:
				tobj.genomic_stopcodon.sort(key=lambda x: x.start, reverse=sorted_reverse)
				tobj.stopcodon = genomic_iv_transform(tobj.genomic_exons,tobj.genomic_stopcodon)
				if len(tobj.stopcodon) >1:
					sys.stderr.write("Warning: the stop codon is discontinuous," +
					                "only first region is used, %s\n" % tobj.transcript_id)
				tobj.stopcodon = tobj.stopcodon[0]
			elif tobj.cds:
				tobj.stopcodon = Interval(tobj.cds.end, tobj.cds.end + 3, "+")
			else:
				pass

			transcript_seq = [genomic_seq.get_seq(tobj.chrom,exon_iv.start,exon_iv.end,exon_iv.strand) for exon_iv in tobj.genomic_exons]
			transcript_seq = "".join(transcript_seq)
			# write the transcript sequence to file
			transcript_seq_file.write(">%s %i\n%s\n" % (tobj.transcript_id,tobj.length,transcript_seq))

		transcript_seq_file.close()
		transcript_cds_file.close()

		## dump the pickle
		sys.stderr.write("\tSaving the transcripts.pickle\n")
		with open(pickle_file,"wb") as fout:
			pickle.dump([gene_dict,transcript_dict],fout,protocol=pickle.HIGHEST_PROTOCOL)

		return gene_dict,transcript_dict

def verboseprint(printstring):
	sys.stderr.write('[%s] %s\n' % (strftime("%Y-%m-%d %H:%M:%S"), printstring))
	sys.stderr.flush()


def main():
	from .parsing_opts import parsing_transcript
	args = parsing_transcript()
	verboseprint("Preparing annotation files ...")
	processTranscripts(args.genomeFasta,args.gtfFile,args.out_dir)
	verboseprint("The step of preparing transcript annotation has been completed.")

# %%
import sys
if sys.version_info.major ==2:
	import cPickle as pickle
else:
	import pickle
	from sys import intern
import os
from pyfasta import Fasta
from time import strftime
import re

class ParsingError(Exception):
	pass

class Interval(object):
	""" basic interval """
	def __init__(self,start,end,strand):
		if end < start:
			raise ValueError('Error: end smaller than start !')

		self.start = start
		self.end = end
		self.strand = strand
		if strand == "+":
			self.start_d = start
			self.end_d = end
		elif strand == "-":
			self.start_d = end - 1
			self.end_d = start - 1
		else:
			raise ValueError('Error: strand is neither "+" nor "-" !')
		self.length = end - start

	def contain(self,start,end):
		if end < start:
			raise ValueError('Error: end smaller than start !')
		if self.start <= start and self.end >= end:
			return True
		else:
			return False

	def contain_iv(self,iv):
		return self.contain(iv.start,iv.end)

	def is_overlapped_with(self, iv):
		if self.start <= iv.start <= self.end or self.start <= iv.end <= self.end:
			return True
		else:
			return False

	def __str__(self):
		return "iv:%i-%i" % (self.start,self.end)

	__repr__ = __str__

def Interval_from_directional(start_d,end_d,strand="-"):
	if strand == "-":
		return Interval(end_d+1,start_d+1,"-")
	else:
		return Interval(start_d,end_d,"+")

def parsing_attr(attr_string):
	attr_dict = {}
	attr_split = re.findall(r'.*? ".*?";', attr_string)
	for i in attr_split:
		if i:
			k,v = i.strip().split(" ",1)
			k = intern(k)
			if v.endswith(";"): v = v[:-1]
			v = intern(v.strip('"'))
			if k == "tag":
				attr_dict.setdefault(k,[]).append(v)
			else:
				attr_dict[k] = v
	return attr_dict

def parsing_line(line):
	"""
        # GTF columns:
        # 1) chrom: str ("1", "X", "chrX", etc...)
        # 2) source : str (not used)
        # 3) feature : str ("gene", "transcript", &c)
        # 4) start : int
        # 5) end : int
        # 6) score : float or "." (not used)
        # 7) strand : "+", "-", or "."
        # 8) frame : 0, 1, 2 or "." (not used)
        # 9) attribute : key-value pairs separated by semicolons
	"""
	chrom,source,feature,start,end,score,strand,frame,attr = line.strip().split("\t",8)
	#convert to 0-based.
	iv = Interval(int(start) - 1, int(end), strand)
	field_dict = {"chrom": intern(chrom),"source":source,"feature": intern(feature),"iv":iv,"attr":parsing_attr(attr)}
	return field_dict

class Gene(object):
	""" Gene object """

	def __init__(self,field_dict):
		self.chrom = field_dict["chrom"]
		self.genomic_iv = field_dict["iv"]
		self.attr = field_dict["attr"]
		self.gene_id = self.attr["gene_id"]
		self.gene_name = self.attr.get("gene_name",self.attr.get("gene_id",None))
		self.gene_type = self.attr.get("gene_type",self.attr.get("gene_biotype",None))
		self.transcripts = []
		self.principal_transcripts = []

	def __str__(self):
		return "GeneID:%s;GeneName:%s;GeneType:%s" % (self.gene_id,self.gene_name,self.gene_type)

	__repr__ = __str__

class Transcript(object):
	""" Transcript object """

	def __init__(self,field_dict):
		self.chrom = field_dict["chrom"]
		self.genomic_iv = field_dict["iv"]
		self.attr = field_dict["attr"]
		self.gene_id = self.attr["gene_id"]
		self.gene_name = self.attr.get("gene_name",self.attr.get("gene_id",None))
		self.transcript_type = self.attr.get("transcript_type",self.attr.get("transcript_biotype",None))
		self.transcript_id = self.attr["transcript_id"]
		self.genomic_exons = []
		self.genomic_cds = []
		self.genomic_startcodon = []
		self.genomic_stopcodon = []
		self.length = 0

		self.cds = None
		self.startcodon = None
		self.stopcodon = None

	def add_feature(self,field_dict):
		feature = field_dict["feature"]
		iv = field_dict["iv"]
		if feature == "exon":
			self.genomic_exons.append(iv)
			self.length += iv.length
		elif feature == "CDS":
			self.genomic_cds.append(iv)
		elif feature == "start_codon":
			self.genomic_startcodon.append(iv)
		elif feature == "stop_codon":
			self.genomic_stopcodon.append(iv)
		else:
			raise ValueError("Error: the feature is not recognized: %s" % feature)

	def __str__(self):
		return "TranscriptID:%s;TranscriptType:%s" % (self.transcript_id,self.transcript_type)

	__repr__ = __str__

def readGTF(filename):
	if not os.path.exists(filename):
		raise IOError("\tGTF file does not exist: %s" % filename)
	sys.stdout.write("\tReading the GTF file: %s .......\n" % filename)
	gene_dict = {}
	transcript_dict = {}
	with open(filename) as fin:
		for i,line in enumerate(fin):
			if line[0] == "#" or (not line.strip()):
				continue
			field_dict = parsing_line(line)
			if field_dict["feature"] == "gene":
				gobj = Gene(field_dict)
				gene_dict[gobj.gene_id] = gobj
			elif field_dict["feature"] == "transcript":
				tobj = Transcript(field_dict)
				transcript_dict[tobj.transcript_id] = tobj
			elif field_dict["feature"] in ["exon","CDS","start_codon","stop_codon"]:
				tid = field_dict["attr"]["transcript_id"]
				try:
					transcript_dict[tid].add_feature(field_dict)
				except KeyError:
					raise ParsingError("Error in line %i. The annotation in GTF file should be three-level hierarchy of \
					                    gene => transcript => exon (or CDS)" % i)
			else:
				pass
	return gene_dict,transcript_dict

def get_chrom(name):
	if " " in name:
		return name.split()[0]
	elif "|" in name:
		return name.split("|")
	else:
		return name

class GenomeSeq(object):
	""" genomic sequence"""

	def __init__(self,filename):
		self.filename = filename
		self.fh = Fasta(filename, key_fn = get_chrom)
	def get_seq(self,chrom,start=0,end=False,strand="+"):
		if end is False:
			end = len(self.fh[chrom])
		return self.fh.sequence({"chr":chrom, "start":start, "stop": end, "strand":strand}, one_based=False)


def genomic_iv_transform(genomic_exons_sorted, genomic_ivs_sorted):
	"""
	transform the genomic interval (of cds, start and stop codons) to inner coordinate in transcript,
	transcript_exons must be sorted
	return 0-based iv
	"""

	length = 0
	innerIV = []
	for i in genomic_exons_sorted:
		for j in genomic_ivs_sorted:
			if i.contain_iv(j):
				start = length + abs(j.start_d - i.start_d)
				end = start + (j.end - j.start)
				if innerIV and start == innerIV[-1].end:
					innerIV[-1] = Interval(innerIV[-1].start, end, "+")
				else:
					innerIV.append(Interval(start,end,"+"))
		length += i.end - i.start
	if len(innerIV) == 0:
		raise ValueError("\tCan't transform the genomic interval, please check!")
	return innerIV

def transcript_pos_transform(tobj, transcript_pos):
	"""
	transform the transcript position to genomic position
	0-based
	if strand is "-", return position of strand.
	"""
	length = 0
	strand = tobj.genomic_iv.strand
	genomic_pos = -1
	for i in tobj.genomic_exons:
		if transcript_pos < length + i.length:
			if strand == "+":
				genomic_pos = transcript_pos - length + i.start
			else:
				genomic_pos = i.start_d - (transcript_pos - length)
			break
		length += i.length
	return genomic_pos

def transcript_iv_transform(tobj, transcript_iv):
	"""
	transform the transcript interval to genomic interval, zero-based.
	"""
	strand = tobj.genomic_iv.strand
	genomic_start = transcript_pos_transform(tobj,transcript_iv.start)
	genomic_end = transcript_pos_transform(tobj,transcript_iv.end-1)
	if strand == "+":
		genomic_end += 1
	else:
		genomic_end -= 1
	exons_bound = [genomic_start]


	for i in tobj.genomic_exons:
		if strand == "+":
			if genomic_start < i.start < genomic_end:
				exons_bound.append(i.start)
			if genomic_start < i.end < genomic_end:
				exons_bound.append(i.end)
		else:
			if genomic_end < i.start_d < genomic_start:
				exons_bound.append(i.start_d)
			if genomic_end < i.end_d < genomic_start:
				exons_bound.append(i.end_d)

	exons_bound.append(genomic_end)
	if len(exons_bound) % 2 != 0:
		print("error when transform the transcript interval to genomic!")
	exons_ivs = []
	for i in range(0,len(exons_bound),2):
		exons_ivs.append(Interval_from_directional(exons_bound[i],exons_bound[i+1],strand))

	return exons_ivs

def load_transcripts_pickle(pickle_file):
	if os.path.exists(pickle_file):
		sys.stdout.write("\tLoading transcripts.pickle ...\n")
		with open(pickle_file,"rb") as fin:
			gene_dict, transcript_dict = pickle.load(fin)
	else:
		raise IOError("\tError, %s file not found\n" % pickle_file)

	return gene_dict,transcript_dict

def processTranscripts(genomeFasta,gtfFile,out_dir):
	"""
	transform the genomic position into the transcript position
	"""
	pickle_file = os.path.join(out_dir,"transcripts.pickle")
	if os.path.exists(pickle_file):
		gene_dict, transcript_dict = load_transcripts_pickle(pickle_file)
		return gene_dict, transcript_dict
	else:
		gene_dict,transcript_dict = readGTF(gtfFile)
		if not os.path.exists(genomeFasta):
			raise IOError("\tError, the genomic fasta file not found: %s" % genomeFasta)
		genomic_seq = GenomeSeq(genomeFasta)
		transcript_seq_file = open(os.path.join(out_dir,"transcripts_sequence.fa"),"w") #title: transcriptid length
		transcript_cds_file = open(os.path.join(out_dir,"transcripts_cds.txt"),"w") # tid, cds_start, cds_end

		sys.stderr.write("\tProcess the transcripts ....\n")
		for tobj in transcript_dict.values():
			# store the transcript id in gene object
			if tobj.transcript_id not in gene_dict[tobj.gene_id].transcripts:
				gene_dict[tobj.gene_id].transcripts.append(tobj.transcript_id)
				if "appris_principal_1" in tobj.attr.get("tag",[]) or "appris_principal" in tobj.attr.get("tag", []):
					gene_dict[tobj.gene_id].principal_transcripts.append(tobj.transcript_id)
			# sort the exons,cds,startcodon,stopcodon according their position on genomic
			if tobj.genomic_iv.strand == "+":
				sorted_reverse = False
			else:
				sorted_reverse = True

			tobj.genomic_exons.sort(key=lambda x: x.start, reverse=sorted_reverse)
			# convert the CDS genomic coordination into transcript coordination
			if tobj.genomic_cds:
				tobj.genomic_cds.sort(key=lambda x: x.start, reverse=sorted_reverse)
				tobj.cds = genomic_iv_transform(tobj.genomic_exons, tobj.genomic_cds)
				if len(tobj.cds) > 1:
					sys.stderr.write("Warning: the CDS is discontinuous," +
					                  "only first region is used, %s\n" % tobj.transcript_id)
				tobj.cds = tobj.cds[0]
				transcript_cds_file.write("%s\t%i\t%i\n" % (tobj.transcript_id,tobj.cds.start +1,tobj.cds.end + 3))

			# start and stop codon
			if tobj.genomic_startcodon:
				tobj.genomic_startcodon.sort(key=lambda x: x.start, reverse=sorted_reverse)
				tobj.startcodon = genomic_iv_transform(tobj.genomic_exons,tobj.genomic_startcodon)
				if len(tobj.startcodon) >1:
					sys.stderr.write("Warning: the start codon is discontinuous," +
					                "only first region is used, %s\n" % tobj.transcript_id)
				tobj.startcodon = tobj.startcodon[0]
			elif tobj.cds:
				tobj.startcodon = Interval(tobj.cds.start, tobj.cds.start + 3, "+")
			else:
				pass

			if tobj.genomic_stopcodon:
				tobj.genomic_stopcodon.sort(key=lambda x: x.start, reverse=sorted_reverse)
				tobj.stopcodon = genomic_iv_transform(tobj.genomic_exons,tobj.genomic_stopcodon)
				if len(tobj.stopcodon) >1:
					sys.stderr.write("Warning: the stop codon is discontinuous," +
					                "only first region is used, %s\n" % tobj.transcript_id)
				tobj.stopcodon = tobj.stopcodon[0]
			elif tobj.cds:
				tobj.stopcodon = Interval(tobj.cds.end, tobj.cds.end + 3, "+")
			else:
				pass

			transcript_seq = [genomic_seq.get_seq(tobj.chrom,exon_iv.start,exon_iv.end,exon_iv.strand) for exon_iv in tobj.genomic_exons]
			transcript_seq = "".join(transcript_seq)
			# write the transcript sequence to file
			transcript_seq_file.write(">%s %i\n%s\n" % (tobj.transcript_id,tobj.length,transcript_seq))

		transcript_seq_file.close()
		transcript_cds_file.close()

		## dump the pickle
		sys.stderr.write("\tSaving the transcripts.pickle\n")
		with open(pickle_file,"wb") as fout:
			pickle.dump([gene_dict,transcript_dict],fout,protocol=pickle.HIGHEST_PROTOCOL)

		return gene_dict,transcript_dict

def verboseprint(printstring):
	sys.stderr.write('[%s] %s\n' % (strftime("%Y-%m-%d %H:%M:%S"), printstring))
	sys.stderr.flush()


def main():
	from .parsing_opts import parsing_transcript
	args = parsing_transcript()
	verboseprint("Preparing annotation files ...")
	processTranscripts(args.genomeFasta,args.gtfFile,args.out_dir)
	verboseprint("The step of preparing transcript annotation has been completed.")

# %%
processTranscripts('/research_jude/rgs01_jude/groups/blancgrp/projects/rRNA_variation/common/metagene_analysis/Mus_musculus.GRCm39.dna.primary_assembly.rdna.fa', 
                   '/research_jude/rgs01_jude/groups/blancgrp/projects/rRNA_variation/common/metagene_analysis/Mus_musculus.GRCm39.104.rdna_rn18s.gtf',
                   '/research_jude/rgs01_jude/groups/blancgrp/projects/rRNA_variation/common/metagene_analysis/output')
# Out:
# 	Loading transcripts.pickle ...
# ({'ENSMUSG00000102628': GeneID:ENSMUSG00000102628;GeneName:Gm37671;GeneType:TEC,
#   'ENSMUSG00000100595': GeneID:ENSMUSG00000100595;GeneName:Gm19087;GeneType:processed_pseudogene,
#   'ENSMUSG00000097426': GeneID:ENSMUSG00000097426;GeneName:Gm8941;GeneType:processed_pseudogene,
#   'ENSMUSG00000104478': GeneID:ENSMUSG00000104478;GeneName:Gm38212;GeneType:TEC,
#   'ENSMUSG00000104385': GeneID:ENSMUSG00000104385;GeneName:Gm7449;GeneType:processed_pseudogene,
#   'ENSMUSG00000086053': GeneID:ENSMUSG00000086053;GeneName:Gm15178;GeneType:lncRNA,
#   'ENSMUSG00000101231': GeneID:ENSMUSG00000101231;GeneName:Gm28283;GeneType:processed_pseudogene,
#   'ENSMUSG00000102135': GeneID:ENSMUSG00000102135;GeneName:Gm37108;GeneType:processed_pseudogene,
#   'ENSMUSG00000103282': GeneID:ENSMUSG00000103282;GeneName:Gm37275;GeneType:processed_pseudogene,
#   'ENSMUSG00000101097': GeneID:ENSMUSG00000101097;GeneName:Gm6679;GeneType:processed_pseudogene,
#   'ENSMUSG00000100764': GeneID:ENSMUSG00000100764;GeneName:Gm29155;GeneType:lncRNA,
#   'ENSMUSG00000102095': GeneID:ENSMUSG00000102095;GeneName:C730036E19Rik;GeneType:lncRNA,
#   'ENSMUSG00000102534': GeneID:ENSMUSG00000102534;GeneName:Gm37225;GeneType:processed_pseudogene,
#   'ENSMUSG00000100831': GeneID:ENSMUSG00000100831;GeneName:Gm17847;GeneType:processed_pseudogene,
#   'ENSMUSG00000100884': GeneID:ENSMUSG00000100884;GeneName:Gm28281;GeneType:processed_pseudogene,
#   'ENSMUSG00000100635': GeneID:ENSMUSG00000100635;GeneName:Gm29157;GeneType:lncRNA,
#   'ENSMUSG00000102213': GeneID:ENSMUSG00000102213;GeneName:Gm37489;GeneType:processed_pseudogene,
#   'ENSMUSG00000100480': GeneID:ENSMUSG00000100480;GeneName:Gm29156;GeneType:lncRNA,
#   'ENSMUSG00000114212': GeneID:ENSMUSG00000114212;GeneName:Gm47985;GeneType:protein_coding,
#   'ENSMUSG00000089037': GeneID:ENSMUSG00000089037;GeneName:Gm22159;GeneType:snoRNA,
#   'ENSMUSG00000103629': GeneID:ENSMUSG00000103629;GeneName:Gm5694;GeneType:processed_pseudogene,
#   'ENSMUSG00000114943': GeneID:ENSMUSG00000114943;GeneName:Gm8947;GeneType:protein_coding,
#   'ENSMUSG00002076531': GeneID:ENSMUSG00002076531;GeneName:7SK;GeneType:misc_RNA,
#   'ENSMUSG00000100025': GeneID:ENSMUSG00000100025;GeneName:Gm8141;GeneType:processed_pseudogene,
#   'ENSMUSG00000114694': GeneID:ENSMUSG00000114694;GeneName:Gm47995;GeneType:protein_coding,
#   'ENSMUSG00000114582': GeneID:ENSMUSG00000114582;GeneName:3110040M04Rik;GeneType:protein_coding,
#   'ENSMUSG00000114591': GeneID:ENSMUSG00000114591;GeneName:Gm47996;GeneType:protein_coding,
#   'ENSMUSG00002076687': GeneID:ENSMUSG00002076687;GeneName:U2;GeneType:snRNA,
#   'ENSMUSG00000100954': GeneID:ENSMUSG00000100954;GeneName:Gm10138;GeneType:lncRNA,
#   'ENSMUSG00000051285': GeneID:ENSMUSG00000051285;GeneName:Pcmtd1;GeneType:protein_coding,
#   'ENSMUSG00000098201': GeneID:ENSMUSG00000098201;GeneName:Gm26983;GeneType:processed_pseudogene,
#   'ENSMUSG00000103509': GeneID:ENSMUSG00000103509;GeneName:Gm38372;GeneType:TEC,
#   'ENSMUSG00000048538': GeneID:ENSMUSG00000048538;GeneName:Gm9826;GeneType:processed_pseudogene,
#   'ENSMUSG00000103709': GeneID:ENSMUSG00000103709;GeneName:Nras-ps2;GeneType:processed_pseudogene,
#   'ENSMUSG00000077244': GeneID:ENSMUSG00000077244;GeneName:Gm23274;GeneType:snoRNA,
#   'ENSMUSG00000102768': GeneID:ENSMUSG00000102768;GeneName:Gm19002;GeneType:processed_pseudogene,
#   'ENSMUSG00000097797': GeneID:ENSMUSG00000097797;GeneName:Gm26901;GeneType:lncRNA,
#   'ENSMUSG00000103498': GeneID:ENSMUSG00000103498;GeneName:Gm18984;GeneType:processed_pseudogene,
#   'ENSMUSG00000103067': GeneID:ENSMUSG00000103067;GeneName:Gm30414;GeneType:lncRNA,
#   'ENSMUSG00000102320': GeneID:ENSMUSG00000102320;GeneName:Gm37791;GeneType:processed_pseudogene,
#   'ENSMUSG00000104226': GeneID:ENSMUSG00000104226;GeneName:Gm7470;GeneType:processed_pseudogene,
#   'ENSMUSG00000103903': GeneID:ENSMUSG00000103903;GeneName:Rps2-ps2;GeneType:processed_pseudogene,
#   'ENSMUSG00000103557': GeneID:ENSMUSG00000103557;GeneName:Gm38216;GeneType:processed_pseudogene,
#   'ENSMUSG00000026312': GeneID:ENSMUSG00000026312;GeneName:Cdh7;GeneType:protein_coding,
#   'ENSMUSG00000100290': GeneID:ENSMUSG00000100290;GeneName:Gm18552;GeneType:processed_pseudogene,
#   'ENSMUSG00000100758': GeneID:ENSMUSG00000100758;GeneName:Gm3332;GeneType:processed_pseudogene,
#   'ENSMUSG00000099926': GeneID:ENSMUSG00000099926;GeneName:Gm6693;GeneType:processed_pseudogene,
#   'ENSMUSG00000039748': GeneID:ENSMUSG00000039748;GeneName:Exo1;GeneType:protein_coding,
#   'ENSMUSG00000118715': GeneID:ENSMUSG00000118715;GeneName:U6;GeneType:snRNA,
#   'ENSMUSG00000104158': GeneID:ENSMUSG00000104158;GeneName:Gm38100;GeneType:protein_coding,
#   'ENSMUSG00000103540': GeneID:ENSMUSG00000103540;GeneName:Gm37668;GeneType:TEC,
#   'ENSMUSG00000057363': GeneID:ENSMUSG00000057363;GeneName:Uxs1;GeneType:protein_coding,
#   'ENSMUSG00000047216': GeneID:ENSMUSG00000047216;GeneName:Cdh19;GeneType:protein_coding,
#   'ENSMUSG00000102788': GeneID:ENSMUSG00000102788;GeneName:Gm38255;GeneType:TEC,
#   'ENSMUSG00000102160': GeneID:ENSMUSG00000102160;GeneName:Gm36944;GeneType:TEC,
#   'ENSMUSG00000101253': GeneID:ENSMUSG00000101253;GeneName:Gm29088;GeneType:lncRNA,
#   'ENSMUSG00000101846': GeneID:ENSMUSG00000101846;GeneName:Gm19927;GeneType:processed_pseudogene,
#   'ENSMUSG00000090243': GeneID:ENSMUSG00000090243;GeneName:Gm16103;GeneType:processed_pseudogene,
#   'ENSMUSG00000100701': GeneID:ENSMUSG00000100701;GeneName:Gm19587;GeneType:processed_pseudogene,
#   'ENSMUSG00000100555': GeneID:ENSMUSG00000100555;GeneName:Gm8173;GeneType:processed_pseudogene,
#   'ENSMUSG00000101395': GeneID:ENSMUSG00000101395;GeneName:Gm8241;GeneType:processed_pseudogene,
#   'ENSMUSG00000102728': GeneID:ENSMUSG00000102728;GeneName:Gm37934;GeneType:TEC,
#   'ENSMUSG00000088848': GeneID:ENSMUSG00000088848;GeneName:Gm26352;GeneType:snoRNA,
#   'ENSMUSG00002075225': GeneID:ENSMUSG00002075225;GeneName:ENSMUSG00002075225;GeneType:miRNA,
#   'ENSMUSG00000038702': GeneID:ENSMUSG00000038702;GeneName:Dsel;GeneType:protein_coding,
#   'ENSMUSG00000101875': GeneID:ENSMUSG00000101875;GeneName:Gm6028;GeneType:processed_pseudogene,
#   'ENSMUSG00000099732': GeneID:ENSMUSG00000099732;GeneName:Gm17752;GeneType:processed_pseudogene,
#   'ENSMUSG00000101220': GeneID:ENSMUSG00000101220;GeneName:Gm6717;GeneType:processed_pseudogene,
#   'ENSMUSG00000100020': GeneID:ENSMUSG00000100020;GeneName:Gm19086;GeneType:processed_pseudogene,
#   'ENSMUSG00000101054': GeneID:ENSMUSG00000101054;GeneName:Gm18406;GeneType:processed_pseudogene,
#   'ENSMUSG00000088691': GeneID:ENSMUSG00000088691;GeneName:Gm22331;GeneType:snoRNA,
#   'ENSMUSG00000099884': GeneID:ENSMUSG00000099884;GeneName:Gm8204;GeneType:processed_pseudogene,
#   'ENSMUSG00000100304': GeneID:ENSMUSG00000100304;GeneName:Gm28190;GeneType:processed_pseudogene,
#   'ENSMUSG00000101453': GeneID:ENSMUSG00000101453;GeneName:Gm28189;GeneType:lncRNA,
#   'ENSMUSG00000102105': GeneID:ENSMUSG00000102105;GeneName:Gm17946;GeneType:processed_pseudogene,
#   'ENSMUSG00000099943': GeneID:ENSMUSG00000099943;GeneName:Gm18181;GeneType:processed_pseudogene,
#   'ENSMUSG00002075119': GeneID:ENSMUSG00002075119;GeneName:ENSMUSG00002075119;GeneType:snoRNA,
#   'ENSMUSG00000097648': GeneID:ENSMUSG00000097648;GeneName:9330185C12Rik;GeneType:lncRNA,
#   'ENSMUSG00000101687': GeneID:ENSMUSG00000101687;GeneName:Gm4854;GeneType:processed_pseudogene,
#   'ENSMUSG00000100515': GeneID:ENSMUSG00000100515;GeneName:Gm17916;GeneType:transcribed_processed_pseudogene,
#   'ENSMUSG00000033021': GeneID:ENSMUSG00000033021;GeneName:Gmppa;GeneType:protein_coding,
#   'ENSMUSG00000055214': GeneID:ENSMUSG00000055214;GeneName:Pld5;GeneType:protein_coding,
#   'ENSMUSG00000078184': GeneID:ENSMUSG00000078184;GeneName:Rbm8a2;GeneType:protein_coding,
#   'ENSMUSG00000104363': GeneID:ENSMUSG00000104363;GeneName:Gm38081;GeneType:TEC,
#   'ENSMUSG00000103277': GeneID:ENSMUSG00000103277;GeneName:Gm37916;GeneType:TEC,
#   'ENSMUSG00000104157': GeneID:ENSMUSG00000104157;GeneName:Gm38101;GeneType:lncRNA,
#   'ENSMUSG00000102446': GeneID:ENSMUSG00000102446;GeneName:Gm17965;GeneType:processed_pseudogene,
#   'ENSMUSG00000104248': GeneID:ENSMUSG00000104248;GeneName:Gm38152;GeneType:TEC,
#   'ENSMUSG00000104021': GeneID:ENSMUSG00000104021;GeneName:Gm36536;GeneType:lncRNA,
#   'ENSMUSG00000103471': GeneID:ENSMUSG00000103471;GeneName:Gm17966;GeneType:processed_pseudogene,
#   'ENSMUSG00000087875': GeneID:ENSMUSG00000087875;GeneName:Gm26104;GeneType:snRNA,
#   'ENSMUSG00000033007': GeneID:ENSMUSG00000033007;GeneName:Asic4;GeneType:protein_coding,
#   'ENSMUSG00000102605': GeneID:ENSMUSG00000102605;GeneName:Gm37264;GeneType:TEC,
#   'ENSMUSG00000070695': GeneID:ENSMUSG00000070695;GeneName:Cntnap5a;GeneType:protein_coding,
#   'ENSMUSG00000025909': GeneID:ENSMUSG00000025909;GeneName:Sntg1;GeneType:protein_coding,
#   'ENSMUSG00002076179': GeneID:ENSMUSG00002076179;GeneName:ENSMUSG00002076179;GeneType:miRNA,
#   'ENSMUSG00000102033': GeneID:ENSMUSG00000102033;GeneName:Gm28263;GeneType:processed_pseudogene,
#   'ENSMUSG00000102647': GeneID:ENSMUSG00000102647;GeneName:Gm38024;GeneType:TEC,
#   'ENSMUSG00000086235': GeneID:ENSMUSG00000086235;GeneName:Gm16284;GeneType:processed_pseudogene,
#   'ENSMUSG00000102253': GeneID:ENSMUSG00000102253;GeneName:Gm38259;GeneType:TEC,
#   'ENSMUSG00002074990': GeneID:ENSMUSG00002074990;GeneName:ENSMUSG00002074990;GeneType:miRNA,
#   'ENSMUSG00000094429': GeneID:ENSMUSG00000094429;GeneName:Gm19965;GeneType:protein_coding,
#   'ENSMUSG00000101154': GeneID:ENSMUSG00000101154;GeneName:Gm17777;GeneType:processed_pseudogene,
#   'ENSMUSG00000103884': GeneID:ENSMUSG00000103884;GeneName:Gm37005;GeneType:TEC,
#   'ENSMUSG00000065865': GeneID:ENSMUSG00000065865;GeneName:Gm24030;GeneType:snRNA,
#   'ENSMUSG00000084353': GeneID:ENSMUSG00000084353;GeneName:Gm15452;GeneType:processed_pseudogene,
#   'ENSMUSG00002076328': GeneID:ENSMUSG00002076328;GeneName:ENSMUSG00002076328;GeneType:miRNA,
#   'ENSMUSG00000103933': GeneID:ENSMUSG00000103933;GeneName:Gm36964;GeneType:processed_pseudogene,
#   'ENSMUSG00000101573': GeneID:ENSMUSG00000101573;GeneName:Gm28361;GeneType:processed_pseudogene,
#   'ENSMUSG00002075967': GeneID:ENSMUSG00002075967;GeneName:ENSMUSG00002075967;GeneType:miRNA,
#   'ENSMUSG00000086195': GeneID:ENSMUSG00000086195;GeneName:Gm6152;GeneType:processed_pseudogene,
#   'ENSMUSG00000107979': GeneID:ENSMUSG00000107979;GeneName:Zfp813-ps;GeneType:lncRNA,
#   'ENSMUSG00000101373': GeneID:ENSMUSG00000101373;GeneName:Zfp813-ps;GeneType:processed_pseudogene,
#   'ENSMUSG00000104504': GeneID:ENSMUSG00000104504;GeneName:Gm7445;GeneType:processed_pseudogene,
#   'ENSMUSG00000099615': GeneID:ENSMUSG00000099615;GeneName:Gm28362;GeneType:unprocessed_pseudogene,
#   'ENSMUSG00000066693': GeneID:ENSMUSG00000066693;GeneName:Gm7493;GeneType:processed_pseudogene,
#   'ENSMUSG00000102316': GeneID:ENSMUSG00000102316;GeneName:Gm37629;GeneType:TEC,
#   'ENSMUSG00000100265': GeneID:ENSMUSG00000100265;GeneName:Gm28363;GeneType:protein_coding,
#   'ENSMUSG00000103819': GeneID:ENSMUSG00000103819;GeneName:Gm38008;GeneType:processed_pseudogene,
#   'ENSMUSG00000100527': GeneID:ENSMUSG00000100527;GeneName:Gm28359;GeneType:unprocessed_pseudogene,
#   'ENSMUSG00000102871': GeneID:ENSMUSG00000102871;GeneName:Gm37143;GeneType:TEC,
#   'ENSMUSG00000099571': GeneID:ENSMUSG00000099571;GeneName:Gm18182;GeneType:unprocessed_pseudogene,
#   'ENSMUSG00000101571': GeneID:ENSMUSG00000101571;GeneName:Gm6187;GeneType:processed_pseudogene,
#   'ENSMUSG00000104428': GeneID:ENSMUSG00000104428;GeneName:Gm18299;GeneType:processed_pseudogene,
#   'ENSMUSG00000101303': GeneID:ENSMUSG00000101303;GeneName:B020011L13Rik;GeneType:protein_coding,
#   'ENSMUSG00000102272': GeneID:ENSMUSG00000102272;GeneName:Gm7512;GeneType:processed_pseudogene,
#   'ENSMUSG00000100305': GeneID:ENSMUSG00000100305;GeneName:Gm28360;GeneType:protein_coding,
#   'ENSMUSG00000065625': GeneID:ENSMUSG00000065625;GeneName:Gm24765;GeneType:snRNA,
#   'ENSMUSG00000099534': GeneID:ENSMUSG00000099534;GeneName:Gm28169;GeneType:processed_pseudogene,
#   'ENSMUSG00000103411': GeneID:ENSMUSG00000103411;GeneName:Gm18300;GeneType:processed_pseudogene,
#   'ENSMUSG00000100886': GeneID:ENSMUSG00000100886;GeneName:Gm7195;GeneType:unprocessed_pseudogene,
#   'ENSMUSG00000101415': GeneID:ENSMUSG00000101415;GeneName:Gm28168;GeneType:protein_coding,
#   'ENSMUSG00000061024': GeneID:ENSMUSG00000061024;GeneName:Rrs1;GeneType:protein_coding,
#   'ENSMUSG00000100617': GeneID:ENSMUSG00000100617;GeneName:Gm7145;GeneType:protein_coding,
#   'ENSMUSG00000100703': GeneID:ENSMUSG00000100703;GeneName:Gm28358;GeneType:transcribed_unprocessed_pseudogene,
#   'ENSMUSG00000100177': GeneID:ENSMUSG00000100177;GeneName:Gm29489;GeneType:unprocessed_pseudogene,
#   'ENSMUSG00000101363': GeneID:ENSMUSG00000101363;GeneName:Gm29490;GeneType:processed_pseudogene,
#   'ENSMUSG00000101590': GeneID:ENSMUSG00000101590;GeneName:Gm29104;GeneType:unprocessed_pseudogene,
#   'ENSMUSG00000102030': GeneID:ENSMUSG00000102030;GeneName:Gm29106;GeneType:protein_coding,
#   'ENSMUSG00000099870': GeneID:ENSMUSG00000099870;GeneName:Gm7200;GeneType:processed_pseudogene,
#   'ENSMUSG00000023150': GeneID:ENSMUSG00000023150;GeneName:Ivns1abp;GeneType:protein_coding,
#   'ENSMUSG00000026374': GeneID:ENSMUSG00000026374;GeneName:Tsn;GeneType:protein_coding,
#   'ENSMUSG00000026377': GeneID:ENSMUSG00000026377;GeneName:Nifk;GeneType:protein_coding,
#   'ENSMUSG00000099936': GeneID:ENSMUSG00000099936;GeneName:Gm28867;GeneType:lncRNA,
#   'ENSMUSG00000025911': GeneID:ENSMUSG00000025911;GeneName:Adhfe1;GeneType:protein_coding,
#   'ENSMUSG00000052748': GeneID:ENSMUSG00000052748;GeneName:Swt1;GeneType:protein_coding,
#   'ENSMUSG00000079671': GeneID:ENSMUSG00000079671;GeneName:2610203C22Rik;GeneType:lncRNA,
#   'ENSMUSG00000081441': GeneID:ENSMUSG00000081441;GeneName:Gm6161;GeneType:processed_pseudogene,
#   'ENSMUSG00000067879': GeneID:ENSMUSG00000067879;GeneName:Vxn;GeneType:protein_coding,
#   'ENSMUSG00000099827': GeneID:ENSMUSG00000099827;GeneName:Gm29520;GeneType:lncRNA,
#   'ENSMUSG00000057335': GeneID:ENSMUSG00000057335;GeneName:Cep170;GeneType:protein_coding,
#   'ENSMUSG00000103634': GeneID:ENSMUSG00000103634;GeneName:3110062G12Rik;GeneType:TEC,
#   'ENSMUSG00000104154': GeneID:ENSMUSG00000104154;GeneName:Gm38104;GeneType:TEC,
#   'ENSMUSG00000103435': GeneID:ENSMUSG00000103435;GeneName:Gm36992;GeneType:lncRNA,
#   'ENSMUSG00000065573': GeneID:ENSMUSG00000065573;GeneName:Mir350;GeneType:miRNA,
#   'ENSMUSG00002076271': GeneID:ENSMUSG00002076271;GeneName:7SK;GeneType:misc_RNA,
#   'ENSMUSG00000053286': GeneID:ENSMUSG00000053286;GeneName:Trmt1l;GeneType:protein_coding,
#   'ENSMUSG00000106406': GeneID:ENSMUSG00000106406;GeneName:Mir7682;GeneType:miRNA,
#   'ENSMUSG00000103928': GeneID:ENSMUSG00000103928;GeneName:Gm37893;GeneType:TEC,
#   'ENSMUSG00000026484': GeneID:ENSMUSG00000026484;GeneName:Rnf2;GeneType:protein_coding,
#   'ENSMUSG00000103238': GeneID:ENSMUSG00000103238;GeneName:Gm36527;GeneType:TEC,
#   'ENSMUSG00000100981': GeneID:ENSMUSG00000100981;GeneName:Gm29072;GeneType:processed_pseudogene,
#   'ENSMUSG00000100551': GeneID:ENSMUSG00000100551;GeneName:Gm19503;GeneType:processed_pseudogene,
#   'ENSMUSG00000100357': GeneID:ENSMUSG00000100357;GeneName:Gm28181;GeneType:lncRNA,
#   'ENSMUSG00000025912': GeneID:ENSMUSG00000025912;GeneName:Mybl1;GeneType:protein_coding,
#   'ENSMUSG00000045210': GeneID:ENSMUSG00000045210;GeneName:Vcpip1;GeneType:protein_coding,
#   'ENSMUSG00000041763': GeneID:ENSMUSG00000041763;GeneName:Tpp2;GeneType:protein_coding,
#   'ENSMUSG00000097893': GeneID:ENSMUSG00000097893;GeneName:1700034P13Rik;GeneType:lncRNA,
#   'ENSMUSG00000026504': GeneID:ENSMUSG00000026504;GeneName:Sdccag8;GeneType:protein_coding,
#   'ENSMUSG00000103367': GeneID:ENSMUSG00000103367;GeneName:Gm38158;GeneType:processed_pseudogene,
#   'ENSMUSG00000103584': GeneID:ENSMUSG00000103584;GeneName:Gm38053;GeneType:unprocessed_pseudogene,
#   'ENSMUSG00002076339': GeneID:ENSMUSG00002076339;GeneName:ENSMUSG00002076339;GeneType:miRNA,
#   'ENSMUSG00000102475': GeneID:ENSMUSG00000102475;GeneName:Gm37246;GeneType:processed_pseudogene,
#   'ENSMUSG00000047343': GeneID:ENSMUSG00000047343;GeneName:Mettl21c;GeneType:protein_coding,
#   'ENSMUSG00000102211': GeneID:ENSMUSG00000102211;GeneName:Gm37490;GeneType:TEC,
#   'ENSMUSG00000087082': GeneID:ENSMUSG00000087082;GeneName:Gm15423;GeneType:lncRNA,
#   'ENSMUSG00000090106': GeneID:ENSMUSG00000090106;GeneName:Gm15838;GeneType:processed_pseudogene,
#   'ENSMUSG00000103251': GeneID:ENSMUSG00000103251;GeneName:Gm37519;GeneType:TEC,
#   'ENSMUSG00000091844': GeneID:ENSMUSG00000091844;GeneName:Gm8251;GeneType:protein_coding,
#   'ENSMUSG00000026483': GeneID:ENSMUSG00000026483;GeneName:Niban1;GeneType:protein_coding,
#   'ENSMUSG00000100594': GeneID:ENSMUSG00000100594;GeneName:2810414N06Rik;GeneType:lncRNA,
#   'ENSMUSG00000082528': GeneID:ENSMUSG00000082528;GeneName:Gm15182;GeneType:processed_pseudogene,
#   'ENSMUSG00000082012': GeneID:ENSMUSG00000082012;GeneName:Gm5257;GeneType:processed_pseudogene,
#   'ENSMUSG00000099996': GeneID:ENSMUSG00000099996;GeneName:Gm29065;GeneType:lncRNA,
#   'ENSMUSG00000101763': GeneID:ENSMUSG00000101763;GeneName:Gm29068;GeneType:processed_pseudogene,
#   'ENSMUSG00000100827': GeneID:ENSMUSG00000100827;GeneName:Gm29069;GeneType:lncRNA,
#   'ENSMUSG00000100553': GeneID:ENSMUSG00000100553;GeneName:Gm17751;GeneType:lncRNA,
#   'ENSMUSG00000098611': GeneID:ENSMUSG00000098611;GeneName:Mir6343;GeneType:miRNA,
#   'ENSMUSG00000100534': GeneID:ENSMUSG00000100534;GeneName:Gm816;GeneType:lncRNA,
#   'ENSMUSG00000102904': GeneID:ENSMUSG00000102904;GeneName:Gm38265;GeneType:TEC,
#   'ENSMUSG00002076350': GeneID:ENSMUSG00002076350;GeneName:5S_rRNA;GeneType:rRNA,
#   'ENSMUSG00000019699': GeneID:ENSMUSG00000019699;GeneName:Akt3;GeneType:protein_coding,
#   'ENSMUSG00000104391': GeneID:ENSMUSG00000104391;GeneName:Gm37960;GeneType:TEC,
#   'ENSMUSG00000102133': GeneID:ENSMUSG00000102133;GeneName:Gm37106;GeneType:TEC,
#   'ENSMUSG00000102749': GeneID:ENSMUSG00000102749;GeneName:Gm37598;GeneType:TEC,
#   'ENSMUSG00000103163': GeneID:ENSMUSG00000103163;GeneName:Gm38146;GeneType:TEC,
#   'ENSMUSG00000103646': GeneID:ENSMUSG00000103646;GeneName:Gm37706;GeneType:TEC,
#   'ENSMUSG00000102427': GeneID:ENSMUSG00000102427;GeneName:Gm37463;GeneType:TEC,
#   'ENSMUSG00000103633': GeneID:ENSMUSG00000103633;GeneName:Gm38328;GeneType:processed_pseudogene,
#   'ENSMUSG00000097892': GeneID:ENSMUSG00000097892;GeneName:Gm26801;GeneType:lncRNA,
#   'ENSMUSG00000063659': GeneID:ENSMUSG00000063659;GeneName:Zbtb18;GeneType:protein_coding,
#   'ENSMUSG00000102432': GeneID:ENSMUSG00000102432;GeneName:Gm29856;GeneType:lncRNA,
#   'ENSMUSG00000103043': GeneID:ENSMUSG00000103043;GeneName:Gm37306;GeneType:lncRNA,
#   'ENSMUSG00000102885': GeneID:ENSMUSG00000102885;GeneName:Gm37280;GeneType:lncRNA,
#   'ENSMUSG00000026049': GeneID:ENSMUSG00000026049;GeneName:Tex30;GeneType:protein_coding,
#   'ENSMUSG00000103767': GeneID:ENSMUSG00000103767;GeneName:Gm37858;GeneType:TEC,
#   'ENSMUSG00000101746': GeneID:ENSMUSG00000101746;GeneName:2310043L19Rik;GeneType:lncRNA,
#   'ENSMUSG00000043019': GeneID:ENSMUSG00000043019;GeneName:Edem3;GeneType:protein_coding,
#   'ENSMUSG00000101104': GeneID:ENSMUSG00000101104;GeneName:Gm29247;GeneType:lncRNA,
#   'ENSMUSG00000015962': GeneID:ENSMUSG00000015962;GeneName:1700016C15Rik;GeneType:protein_coding,
#   'ENSMUSG00000032666': GeneID:ENSMUSG00000032666;GeneName:1700025G04Rik;GeneType:protein_coding,
#   'ENSMUSG00000084557': GeneID:ENSMUSG00000084557;GeneName:Gm25279;GeneType:snRNA,
#   'ENSMUSG00000100685': GeneID:ENSMUSG00000100685;GeneName:Gm28610;GeneType:lncRNA,
#   'ENSMUSG00000102090': GeneID:ENSMUSG00000102090;GeneName:Gm8964;GeneType:processed_pseudogene,
#   'ENSMUSG00000103744': GeneID:ENSMUSG00000103744;GeneName:Gm38238;GeneType:TEC,
#   'ENSMUSG00000015961': GeneID:ENSMUSG00000015961;GeneName:Adss;GeneType:protein_coding,
#   'ENSMUSG00000089657': GeneID:ENSMUSG00000089657;GeneName:Gm16585;GeneType:processed_pseudogene,
#   'ENSMUSG00000102483': GeneID:ENSMUSG00000102483;GeneName:Catspere1;GeneType:protein_coding,
#   'ENSMUSG00000014980': GeneID:ENSMUSG00000014980;GeneName:Tsen15;GeneType:protein_coding,
#   'ENSMUSG00000026235': GeneID:ENSMUSG00000026235;GeneName:Epha4;GeneType:protein_coding,
#   'ENSMUSG00000099141': GeneID:ENSMUSG00000099141;GeneName:Mir6352;GeneType:miRNA,
#   'ENSMUSG00000032649': GeneID:ENSMUSG00000032649;GeneName:Colgalt2;GeneType:protein_coding,
#   'ENSMUSG00000101849': GeneID:ENSMUSG00000101849;GeneName:Gm28386;GeneType:lncRNA,
#   'ENSMUSG00000101506': GeneID:ENSMUSG00000101506;GeneName:Gm28385;GeneType:processed_pseudogene,
#   'ENSMUSG00000065215': GeneID:ENSMUSG00000065215;GeneName:Gm26263;GeneType:snRNA,
#   'ENSMUSG00000102052': GeneID:ENSMUSG00000102052;GeneName:Gm28387;GeneType:lncRNA,
#   'ENSMUSG00000026047': GeneID:ENSMUSG00000026047;GeneName:Poglut2;GeneType:protein_coding,
#   'ENSMUSG00000080878': GeneID:ENSMUSG00000080878;GeneName:Btf3-ps14;GeneType:processed_pseudogene,
#   'ENSMUSG00000091476': GeneID:ENSMUSG00000091476;GeneName:Catspere2;GeneType:protein_coding,
#   'ENSMUSG00000104097': GeneID:ENSMUSG00000104097;GeneName:Gm37313;GeneType:unprocessed_pseudogene,
#   'ENSMUSG00000119789': GeneID:ENSMUSG00000119789;GeneName:U6;GeneType:snRNA,
#   'ENSMUSG00000102493': GeneID:ENSMUSG00000102493;GeneName:Gm8010;GeneType:unprocessed_pseudogene,
#   'ENSMUSG00000004872': GeneID:ENSMUSG00000004872;GeneName:Pax3;GeneType:protein_coding,
#   'ENSMUSG00000118426': GeneID:ENSMUSG00000118426;GeneName:Gm2102;GeneType:processed_pseudogene,
#   'ENSMUSG00000041684': GeneID:ENSMUSG00000041684;GeneName:Bivm;GeneType:protein_coding,
#   'ENSMUSG00000032908': GeneID:ENSMUSG00000032908;GeneName:Sgpp2;GeneType:protein_coding,
#   'ENSMUSG00000099561': GeneID:ENSMUSG00000099561;GeneName:Gm28410;GeneType:lncRNA,
#   'ENSMUSG00000102945': GeneID:ENSMUSG00000102945;GeneName:Gm37884;GeneType:TEC,
#   'ENSMUSG00000026502': GeneID:ENSMUSG00000026502;GeneName:Desi2;GeneType:protein_coding,
#   'ENSMUSG00000103958': GeneID:ENSMUSG00000103958;GeneName:Gm8023;GeneType:processed_pseudogene,
#   'ENSMUSG00000070489': GeneID:ENSMUSG00000070489;GeneName:4930527J03Rik;GeneType:pseudogene,
#   'ENSMUSG00000104126': GeneID:ENSMUSG00000104126;GeneName:Gm37486;GeneType:processed_pseudogene,
#   'ENSMUSG00000086350': GeneID:ENSMUSG00000086350;GeneName:B230369F24Rik;GeneType:lncRNA,
#   'ENSMUSG00000026500': GeneID:ENSMUSG00000026500;GeneName:Cox20;GeneType:protein_coding,
#   'ENSMUSG00000026048': GeneID:ENSMUSG00000026048;GeneName:Ercc5;GeneType:protein_coding,
#   'ENSMUSG00000046828': GeneID:ENSMUSG00000046828;GeneName:Mettl21e;GeneType:protein_coding,
#   'ENSMUSG00000089703': GeneID:ENSMUSG00000089703;GeneName:Gm15833;GeneType:processed_pseudogene,
#   'ENSMUSG00000100966': GeneID:ENSMUSG00000100966;GeneName:Gm5700;GeneType:processed_pseudogene,
#   'ENSMUSG00000100769': GeneID:ENSMUSG00000100769;GeneName:Gm28893;GeneType:lncRNA,
#   'ENSMUSG00000101567': GeneID:ENSMUSG00000101567;GeneName:Txn-ps1;GeneType:processed_pseudogene,
#   'ENSMUSG00000026245': GeneID:ENSMUSG00000026245;GeneName:Farsb;GeneType:protein_coding,
#   'ENSMUSG00000101798': GeneID:ENSMUSG00000101798;GeneName:Gm28995;GeneType:unprocessed_pseudogene,
#   'ENSMUSG00000104018': GeneID:ENSMUSG00000104018;GeneName:4833412K13Rik;GeneType:TEC,
#   'ENSMUSG00000090486': GeneID:ENSMUSG00000090486;GeneName:BC035947;GeneType:protein_coding,
#   'ENSMUSG00000026482': GeneID:ENSMUSG00000026482;GeneName:Rgl1;GeneType:protein_coding,
#   'ENSMUSG00000086145': GeneID:ENSMUSG00000086145;GeneName:Gm15479;GeneType:lncRNA,
#   'ENSMUSG00000080950': GeneID:ENSMUSG00000080950;GeneName:Gm7278;GeneType:processed_pseudogene,
#   'ENSMUSG00000099868': GeneID:ENSMUSG00000099868;GeneName:Gm28792;GeneType:lncRNA,
#   'ENSMUSG00000055547': GeneID:ENSMUSG00000055547;GeneName:Apobec4;GeneType:protein_coding,
#   'ENSMUSG00000012187': GeneID:ENSMUSG00000012187;GeneName:Mogat1;GeneType:protein_coding,
#   'ENSMUSG00000008475': GeneID:ENSMUSG00000008475;GeneName:Arpc5;GeneType:protein_coding,
#   'ENSMUSG00000099364': GeneID:ENSMUSG00000099364;GeneName:5730419F03Rik;GeneType:lncRNA,
#   'ENSMUSG00000100562': GeneID:ENSMUSG00000100562;GeneName:Gm29611;GeneType:lncRNA,
#   'ENSMUSG00000056870': GeneID:ENSMUSG00000056870;GeneName:Gulp1;GeneType:protein_coding,
#   'ENSMUSG00000102319': GeneID:ENSMUSG00000102319;GeneName:Gm37626;GeneType:TEC,
#   'ENSMUSG00000089877': GeneID:ENSMUSG00000089877;GeneName:Gm16102;GeneType:processed_pseudogene,
#   'ENSMUSG00000101701': GeneID:ENSMUSG00000101701;GeneName:4930521E06Rik;GeneType:lncRNA,
#   'ENSMUSG00000103071': GeneID:ENSMUSG00000103071;GeneName:Gm38110;GeneType:TEC,
#   'ENSMUSG00000100434': GeneID:ENSMUSG00000100434;GeneName:Gm3489;GeneType:processed_pseudogene,
#   'ENSMUSG00000100013': GeneID:ENSMUSG00000100013;GeneName:Gm19480;GeneType:processed_pseudogene,
#   'ENSMUSG00000101251': GeneID:ENSMUSG00000101251;GeneName:Gm3496;GeneType:processed_pseudogene,
#   'ENSMUSG00000101937': GeneID:ENSMUSG00000101937;GeneName:Gm5268;GeneType:processed_pseudogene,
#   'ENSMUSG00000039630': GeneID:ENSMUSG00000039630;GeneName:Hnrnpu;GeneType:protein_coding,
#   'ENSMUSG00000104279': GeneID:ENSMUSG00000104279;GeneName:Gm38300;GeneType:TEC,
#   'ENSMUSG00002075531': GeneID:ENSMUSG00002075531;GeneName:ENSMUSG00002075531;GeneType:miRNA,
#   'ENSMUSG00000064954': GeneID:ENSMUSG00000064954;GeneName:Gm24919;GeneType:snRNA,
#   'ENSMUSG00000026495': GeneID:ENSMUSG00000026495;GeneName:Efcab2;GeneType:protein_coding,
#   'ENSMUSG00000032883': GeneID:ENSMUSG00000032883;GeneName:Acsl3;GeneType:protein_coding,
#   'ENSMUSG00000026480': GeneID:ENSMUSG00000026480;GeneName:Ncf2;GeneType:protein_coding,
#   'ENSMUSG00000026494': GeneID:ENSMUSG00000026494;GeneName:Kif26b;GeneType:protein_coding,
#   'ENSMUSG00000064967': GeneID:ENSMUSG00000064967;GeneName:Gm24405;GeneType:snRNA,
#   'ENSMUSG00000102922': GeneID:ENSMUSG00000102922;GeneName:Gm34176;GeneType:processed_pseudogene,
#   'ENSMUSG00000025915': GeneID:ENSMUSG00000025915;GeneName:Sgk3;GeneType:protein_coding,
#   'ENSMUSG00000089713': GeneID:ENSMUSG00000089713;GeneName:Gm16564;GeneType:lncRNA,
#   'ENSMUSG00000079470': GeneID:ENSMUSG00000079470;GeneName:Utp14b;GeneType:protein_coding,
#   'ENSMUSG00000099377': GeneID:ENSMUSG00000099377;GeneName:Gm6159;GeneType:processed_pseudogene,
#   'ENSMUSG00000099706': GeneID:ENSMUSG00000099706;GeneName:Gm29536;GeneType:lncRNA,
#   'ENSMUSG00000047330': GeneID:ENSMUSG00000047330;GeneName:Kcne4;GeneType:protein_coding,
#   'ENSMUSG00000101324': GeneID:ENSMUSG00000101324;GeneName:Gm29187;GeneType:lncRNA,
#   'ENSMUSG00000072978': GeneID:ENSMUSG00000072978;GeneName:Gm5830;GeneType:processed_pseudogene,
#   'ENSMUSG00000046334': GeneID:ENSMUSG00000046334;GeneName:Gm6195;GeneType:processed_pseudogene,
#   'ENSMUSG00002075801': GeneID:ENSMUSG00002075801;GeneName:U6;GeneType:snRNA,
#   'ENSMUSG00000050711': GeneID:ENSMUSG00000050711;GeneName:Scg2;GeneType:protein_coding,
#   'ENSMUSG00000099562': GeneID:ENSMUSG00000099562;GeneName:Gm19027;GeneType:processed_pseudogene,
#   'ENSMUSG00000077782': GeneID:ENSMUSG00000077782;GeneName:Gm24160;GeneType:snoRNA,
#   'ENSMUSG00000055067': GeneID:ENSMUSG00000055067;GeneName:Smyd3;GeneType:protein_coding,
#   'ENSMUSG00000054702': GeneID:ENSMUSG00000054702;GeneName:Ap1s3;GeneType:protein_coding,
#   'ENSMUSG00000096474': GeneID:ENSMUSG00000096474;GeneName:Gm5561;GeneType:processed_pseudogene,
#   'ENSMUSG00000102235': GeneID:ENSMUSG00000102235;GeneName:Gm37886;GeneType:TEC,
#   'ENSMUSG00000026492': GeneID:ENSMUSG00000026492;GeneName:Tfb2m;GeneType:protein_coding,
#   'ENSMUSG00000082395': GeneID:ENSMUSG00000082395;GeneName:Gm15480;GeneType:processed_pseudogene,
#   'ENSMUSG00000038949': GeneID:ENSMUSG00000038949;GeneName:Cnst;GeneType:protein_coding,
#   'ENSMUSG00000026043': GeneID:ENSMUSG00000026043;GeneName:Col3a1;GeneType:protein_coding,
#   'ENSMUSG00000046101': GeneID:ENSMUSG00000046101;GeneName:Mcmdc2;GeneType:protein_coding,
#   'ENSMUSG00002074901': GeneID:ENSMUSG00002074901;GeneName:ENSMUSG00002074901;GeneType:miRNA,
#   'ENSMUSG00000098234': GeneID:ENSMUSG00000098234;GeneName:Snhg6;GeneType:lncRNA,
#   'ENSMUSG00000093178': GeneID:ENSMUSG00000093178;GeneName:Snord87;GeneType:snoRNA,
#   'ENSMUSG00000099032': GeneID:ENSMUSG00000099032;GeneName:Tcf24;GeneType:protein_coding,
#   'ENSMUSG00000104025': GeneID:ENSMUSG00000104025;GeneName:E330040D14Rik;GeneType:TEC,
#   'ENSMUSG00000038936': GeneID:ENSMUSG00000038936;GeneName:Sccpdh;GeneType:protein_coding,
#   'ENSMUSG00000042772': GeneID:ENSMUSG00000042772;GeneName:Smg7;GeneType:protein_coding,
#   'ENSMUSG00000100394': GeneID:ENSMUSG00000100394;GeneName:Gm28791;GeneType:lncRNA,
#   'ENSMUSG00000103840': GeneID:ENSMUSG00000103840;GeneName:1700040K01Rik;GeneType:TEC,
#   'ENSMUSG00000087236': GeneID:ENSMUSG00000087236;GeneName:Kif28;GeneType:protein_coding,
#   'ENSMUSG00000100702': GeneID:ENSMUSG00000100702;GeneName:Gm8976;GeneType:processed_pseudogene,
#   'ENSMUSG00000026042': GeneID:ENSMUSG00000026042;GeneName:Col5a2;GeneType:protein_coding,
#   'ENSMUSG00000104476': GeneID:ENSMUSG00000104476;GeneName:Gm38211;GeneType:TEC,
#   'ENSMUSG00000100218': GeneID:ENSMUSG00000100218;GeneName:Gm8296;GeneType:processed_pseudogene,
#   'ENSMUSG00000073643': GeneID:ENSMUSG00000073643;GeneName:Wdfy1;GeneType:protein_coding,
#   'ENSMUSG00000100361': GeneID:ENSMUSG00000100361;GeneName:Gm7063;GeneType:processed_pseudogene,
#   'ENSMUSG00000104497': GeneID:ENSMUSG00000104497;GeneName:Gm10555;GeneType:TEC,
#   'ENSMUSG00000100894': GeneID:ENSMUSG00000100894;GeneName:Gm8304;GeneType:processed_pseudogene,
#   'ENSMUSG00000119267': GeneID:ENSMUSG00000119267;GeneName:U6;GeneType:snRNA,
#   'ENSMUSG00000065255': GeneID:ENSMUSG00000065255;GeneName:Gm23974;GeneType:snoRNA,
#   'ENSMUSG00000100843': GeneID:ENSMUSG00000100843;GeneName:Gm8307;GeneType:processed_pseudogene,
#   'ENSMUSG00000025916': GeneID:ENSMUSG00000025916;GeneName:Ppp1r42;GeneType:protein_coding,
#   'ENSMUSG00000087764': GeneID:ENSMUSG00000087764;GeneName:Gm23984;GeneType:ribozyme,
#   'ENSMUSG00000087199': GeneID:ENSMUSG00000087199;GeneName:Gm15818;GeneType:lncRNA,
#   'ENSMUSG00000026248': GeneID:ENSMUSG00000026248;GeneName:Mrpl44;GeneType:protein_coding,
#   'ENSMUSG00000119658': GeneID:ENSMUSG00000119658;GeneName:U6;GeneType:snRNA,
#   'ENSMUSG00000026249': GeneID:ENSMUSG00000026249;GeneName:Serpine2;GeneType:protein_coding,
#   'ENSMUSG00000042751': GeneID:ENSMUSG00000042751;GeneName:Nmnat2;GeneType:protein_coding,
#   'ENSMUSG00000067106': GeneID:ENSMUSG00000067106;GeneName:Gm5529;GeneType:processed_pseudogene,
#   'ENSMUSG00000099969': GeneID:ENSMUSG00000099969;GeneName:Gm28960;GeneType:lncRNA,
#   'ENSMUSG00000100397': GeneID:ENSMUSG00000100397;GeneName:Gm28071;GeneType:processed_pseudogene,
#   'ENSMUSG00000099753': GeneID:ENSMUSG00000099753;GeneName:Gm28058;GeneType:processed_pseudogene,
#   'ENSMUSG00000118883': GeneID:ENSMUSG00000118883;GeneName:U6;GeneType:snRNA,
#   'ENSMUSG00000102518': GeneID:ENSMUSG00000102518;GeneName:Gm38339;GeneType:TEC,
#   'ENSMUSG00000099552': GeneID:ENSMUSG00000099552;GeneName:9830004L10Rik;GeneType:lncRNA,
#   'ENSMUSG00000043230': GeneID:ENSMUSG00000043230;GeneName:Fam124b;GeneType:protein_coding,
#   'ENSMUSG00000101257': GeneID:ENSMUSG00000101257;GeneName:2310015K22Rik;GeneType:lncRNA,
#   'ENSMUSG00000103404': GeneID:ENSMUSG00000103404;GeneName:Gm37932;GeneType:TEC,
#   'ENSMUSG00000026491': GeneID:ENSMUSG00000026491;GeneName:Ahctf1;GeneType:protein_coding,
#   'ENSMUSG00000073486': GeneID:ENSMUSG00000073486;GeneName:Gm10518;GeneType:lncRNA,
#   'ENSMUSG00000025917': GeneID:ENSMUSG00000025917;GeneName:Cops5;GeneType:protein_coding,
#   'ENSMUSG00000104418': GeneID:ENSMUSG00000104418;GeneName:Gm37070;GeneType:processed_pseudogene,
#   'ENSMUSG00000025995': GeneID:ENSMUSG00000025995;GeneName:Wdr75;GeneType:protein_coding,
#   'ENSMUSG00000026479': GeneID:ENSMUSG00000026479;GeneName:Lamc2;GeneType:protein_coding,
#   'ENSMUSG00000099850': GeneID:ENSMUSG00000099850;GeneName:Gm28906;GeneType:processed_pseudogene,
#   'ENSMUSG00000084817': GeneID:ENSMUSG00000084817;GeneName:Gm5526;GeneType:processed_pseudogene,
#   'ENSMUSG00000004364': GeneID:ENSMUSG00000004364;GeneName:Cul3;GeneType:protein_coding,
#   'ENSMUSG00000103076': GeneID:ENSMUSG00000103076;GeneName:Gm37902;GeneType:TEC,
#   'ENSMUSG00000103525': GeneID:ENSMUSG00000103525;GeneName:Gm37262;GeneType:TEC,
#   'ENSMUSG00000101722': GeneID:ENSMUSG00000101722;GeneName:Gm29125;GeneType:lncRNA,
#   'ENSMUSG00000090637': GeneID:ENSMUSG00000090637;GeneName:Gm6189;GeneType:processed_pseudogene,
#   'ENSMUSG00000026478': GeneID:ENSMUSG00000026478;GeneName:Lamc1;GeneType:protein_coding,
#   'ENSMUSG00000101483': GeneID:ENSMUSG00000101483;GeneName:1700016L21Rik;GeneType:lncRNA,
#   'ENSMUSG00000110100': GeneID:ENSMUSG00000110100;GeneName:Gm45261;GeneType:protein_coding,
#   'ENSMUSG00000103818': GeneID:ENSMUSG00000103818;GeneName:Gm38009;GeneType:TEC,
#   'ENSMUSG00000079138': GeneID:ENSMUSG00000079138;GeneName:Gm8818;GeneType:processed_pseudogene,
#   'ENSMUSG00000073538': GeneID:ENSMUSG00000073538;GeneName:E330020D12Rik;GeneType:lncRNA,
#   'ENSMUSG00000042708': GeneID:ENSMUSG00000042708;GeneName:Shcbp1l;GeneType:protein_coding,
#   'ENSMUSG00000064435': GeneID:ENSMUSG00000064435;GeneName:Gm25588;GeneType:snoRNA,
#   'ENSMUSG00000103543': GeneID:ENSMUSG00000103543;GeneName:Gm37669;GeneType:TEC,
#   'ENSMUSG00000099432': GeneID:ENSMUSG00000099432;GeneName:Gm18849;GeneType:unprocessed_pseudogene,
#   'ENSMUSG00000041144': GeneID:ENSMUSG00000041144;GeneName:Dnah7b;GeneType:protein_coding,
#   'ENSMUSG00000119743': GeneID:ENSMUSG00000119743;GeneName:5S_rRNA;GeneType:rRNA,
#   'ENSMUSG00000042699': GeneID:ENSMUSG00000042699;GeneName:Dhx9;GeneType:protein_coding,
#   'ENSMUSG00000101262': GeneID:ENSMUSG00000101262;GeneName:Gm8326;GeneType:processed_pseudogene,
#   'ENSMUSG00000042684': GeneID:ENSMUSG00000042684;GeneName:Npl;GeneType:protein_coding,
#   'ENSMUSG00000099858': GeneID:ENSMUSG00000099858;GeneName:Gm6652;GeneType:processed_pseudogene,
#   'ENSMUSG00000101337': GeneID:ENSMUSG00000101337;GeneName:Dnah7c;GeneType:protein_coding,
#   'ENSMUSG00000025986': GeneID:ENSMUSG00000025986;GeneName:Slc39a10;GeneType:protein_coding,
#   'ENSMUSG00000100213': GeneID:ENSMUSG00000100213;GeneName:Gm28151;GeneType:lncRNA,
#   'ENSMUSG00000103129': GeneID:ENSMUSG00000103129;GeneName:Gm37393;GeneType:TEC,
#   'ENSMUSG00000100160': GeneID:ENSMUSG00000100160;GeneName:Gm28527;GeneType:processed_pseudogene,
#   'ENSMUSG00000101921': GeneID:ENSMUSG00000101921;GeneName:Gm28825;GeneType:processed_pseudogene,
#   'ENSMUSG00000101447': GeneID:ENSMUSG00000101447;GeneName:Gm28826;GeneType:lncRNA,
#   'ENSMUSG00000081185': GeneID:ENSMUSG00000081185;GeneName:Gm4852;GeneType:processed_pseudogene,
#   'ENSMUSG00000103246': GeneID:ENSMUSG00000103246;GeneName:Gm38090;GeneType:TEC,
#   'ENSMUSG00000098876': GeneID:ENSMUSG00000098876;GeneName:Mir6350;GeneType:miRNA,
#   'ENSMUSG00000100530': GeneID:ENSMUSG00000100530;GeneName:Gm18117;GeneType:processed_pseudogene,
#   'ENSMUSG00000104067': GeneID:ENSMUSG00000104067;GeneName:Gm37196;GeneType:TEC,
#   'ENSMUSG00000100033': GeneID:ENSMUSG00000100033;GeneName:Gm8337;GeneType:processed_pseudogene,
#   'ENSMUSG00002075213': GeneID:ENSMUSG00002075213;GeneName:ENSMUSG00002075213;GeneType:miRNA,
#   'ENSMUSG00002076633': GeneID:ENSMUSG00002076633;GeneName:7SK;GeneType:misc_RNA,
#   'ENSMUSG00000101996': GeneID:ENSMUSG00000101996;GeneName:Gm19206;GeneType:processed_pseudogene,
#   'ENSMUSG00000096973': GeneID:ENSMUSG00000096973;GeneName:Gm5974;GeneType:processed_pseudogene,
#   'ENSMUSG00000064943': GeneID:ENSMUSG00000064943;GeneName:Gm23240;GeneType:snRNA,
#   'ENSMUSG00000100866': GeneID:ENSMUSG00000100866;GeneName:Gm28830;GeneType:processed_pseudogene,
#   'ENSMUSG00000101721': GeneID:ENSMUSG00000101721;GeneName:Gm8354;GeneType:processed_pseudogene,
#   'ENSMUSG00000099376': GeneID:ENSMUSG00000099376;GeneName:Gm19124;GeneType:processed_pseudogene,
#   'ENSMUSG00000097883': GeneID:ENSMUSG00000097883;GeneName:Gm8357;GeneType:processed_pseudogene,
#   'ENSMUSG00002076043': GeneID:ENSMUSG00002076043;GeneName:ENSMUSG00002076043;GeneType:miRNA,
#   'ENSMUSG00000099698': GeneID:ENSMUSG00000099698;GeneName:Gm28740;GeneType:processed_pseudogene,
#   'ENSMUSG00000056763': GeneID:ENSMUSG00000056763;GeneName:Cspp1;GeneType:protein_coding,
#   'ENSMUSG00000099454': GeneID:ENSMUSG00000099454;GeneName:Gm8367;GeneType:processed_pseudogene,
#   'ENSMUSG00000051616': GeneID:ENSMUSG00000051616;GeneName:C230029F24Rik;GeneType:lncRNA,
#   'ENSMUSG00000099627': GeneID:ENSMUSG00000099627;GeneName:Gm6757;GeneType:processed_pseudogene,
#   'ENSMUSG00000099577': GeneID:ENSMUSG00000099577;GeneName:Gm3605;GeneType:processed_pseudogene,
#   'ENSMUSG00000099882': GeneID:ENSMUSG00000099882;GeneName:Gm28388;GeneType:processed_pseudogene,
#   'ENSMUSG00000101760': GeneID:ENSMUSG00000101760;GeneName:Gm8384;GeneType:processed_pseudogene,
#   'ENSMUSG00000102356': GeneID:ENSMUSG00000102356;GeneName:1700047N06Rik;GeneType:TEC,
#   'ENSMUSG00000099608': GeneID:ENSMUSG00000099608;GeneName:4933411E06Rik;GeneType:lncRNA,
#   'ENSMUSG00000099864': GeneID:ENSMUSG00000099864;GeneName:Gm8391;GeneType:processed_pseudogene,
#   'ENSMUSG00002075839': GeneID:ENSMUSG00002075839;GeneName:ENSMUSG00002075839;GeneType:misc_RNA,
#   'ENSMUSG00000100451': GeneID:ENSMUSG00000100451;GeneName:Gm29665;GeneType:lncRNA,
#   'ENSMUSG00000099941': GeneID:ENSMUSG00000099941;GeneName:Gm20118;GeneType:processed_pseudogene,
#   'ENSMUSG00002075589': GeneID:ENSMUSG00002075589;GeneName:7SK;GeneType:misc_RNA,
#   'ENSMUSG00000100816': GeneID:ENSMUSG00000100816;GeneName:Gm28321;GeneType:lncRNA,
#   'ENSMUSG00000042671': GeneID:ENSMUSG00000042671;GeneName:Rgs8;GeneType:protein_coding,
#   'ENSMUSG00000100945': GeneID:ENSMUSG00000100945;GeneName:Gm29529;GeneType:lncRNA,
#   'ENSMUSG00000102404': GeneID:ENSMUSG00000102404;GeneName:5530400K19Rik;GeneType:TEC,
#   'ENSMUSG00000100334': GeneID:ENSMUSG00000100334;GeneName:C230024C17Rik;GeneType:lncRNA,
#   'ENSMUSG00000026109': GeneID:ENSMUSG00000026109;GeneName:Tmeff2;GeneType:protein_coding,
#   'ENSMUSG00000026475': GeneID:ENSMUSG00000026475;GeneName:Rgs16;GeneType:protein_coding,
#   'ENSMUSG00000099568': GeneID:ENSMUSG00000099568;GeneName:Gm28513;GeneType:lncRNA,
#   'ENSMUSG00000100671': GeneID:ENSMUSG00000100671;GeneName:Gm28322;GeneType:lncRNA,
#   'ENSMUSG00002075527': GeneID:ENSMUSG00002075527;GeneName:ENSMUSG00002075527;GeneType:miRNA,
#   'ENSMUSG00000101242': GeneID:ENSMUSG00000101242;GeneName:Gm28319;GeneType:lncRNA,
#   'ENSMUSG00000099924': GeneID:ENSMUSG00000099924;GeneName:Gm28320;GeneType:lncRNA,
#   'ENSMUSG00000099625': GeneID:ENSMUSG00000099625;GeneName:Gm29325;GeneType:lncRNA,
#   'ENSMUSG00000101799': GeneID:ENSMUSG00000101799;GeneName:9330175M20Rik;GeneType:lncRNA,
#   'ENSMUSG00000045954': GeneID:ENSMUSG00000045954;GeneName:Cavin2;GeneType:protein_coding,
#   'ENSMUSG00000099741': GeneID:ENSMUSG00000099741;GeneName:Gm5253;GeneType:processed_pseudogene,
#   'ENSMUSG00000101702': GeneID:ENSMUSG00000101702;GeneName:1700072G22Rik;GeneType:lncRNA,
#   'ENSMUSG00000066800': GeneID:ENSMUSG00000066800;GeneName:Rnasel;GeneType:protein_coding,
#   'ENSMUSG00000100183': GeneID:ENSMUSG00000100183;GeneName:Gm28512;GeneType:lncRNA,
#   'ENSMUSG00000067851': GeneID:ENSMUSG00000067851;GeneName:Arfgef1;GeneType:protein_coding,
#   'ENSMUSG00002076532': GeneID:ENSMUSG00002076532;GeneName:7SK;GeneType:misc_RNA,
#   'ENSMUSG00000102556': GeneID:ENSMUSG00000102556;GeneName:Gm37569;GeneType:TEC,
#   'ENSMUSG00000038608': GeneID:ENSMUSG00000038608;GeneName:Dock10;GeneType:protein_coding,
#   'ENSMUSG00000042501': GeneID:ENSMUSG00000042501;GeneName:Cpa6;GeneType:protein_coding,
#   'ENSMUSG00000103810': GeneID:ENSMUSG00000103810;GeneName:Gm38005;GeneType:TEC,
#   'ENSMUSG00000083422': GeneID:ENSMUSG00000083422;GeneName:Gm15604;GeneType:processed_pseudogene,
#   'ENSMUSG00000119312': GeneID:ENSMUSG00000119312;GeneName:U6;GeneType:snRNA,
#   'ENSMUSG00000042641': GeneID:ENSMUSG00000042641;GeneName:Rgsl1;GeneType:protein_coding,
#   'ENSMUSG00000081417': GeneID:ENSMUSG00000081417;GeneName:Gm15603;GeneType:processed_pseudogene,
#   'ENSMUSG00000103448': GeneID:ENSMUSG00000103448;GeneName:Gm37133;GeneType:TEC,
#   'ENSMUSG00000103192': GeneID:ENSMUSG00000103192;GeneName:Gm37645;GeneType:TEC,
#   'ENSMUSG00000104488': GeneID:ENSMUSG00000104488;GeneName:Gm38062;GeneType:TEC,
#   'ENSMUSG00000100212': GeneID:ENSMUSG00000100212;GeneName:Gm5522;GeneType:processed_pseudogene,
#   'ENSMUSG00000102721': GeneID:ENSMUSG00000102721;GeneName:A630081D01Rik;GeneType:TEC,
#   'ENSMUSG00000100648': GeneID:ENSMUSG00000100648;GeneName:Gm28659;GeneType:processed_pseudogene,
#   'ENSMUSG00002076499': GeneID:ENSMUSG00002076499;GeneName:SNORA66;GeneType:snoRNA,
#   'ENSMUSG00000099949': GeneID:ENSMUSG00000099949;GeneName:Gm29124;GeneType:processed_pseudogene,
#   'ENSMUSG00000099918': GeneID:ENSMUSG00000099918;GeneName:Gm28066;GeneType:processed_pseudogene,
#   'ENSMUSG00000045968': GeneID:ENSMUSG00000045968;GeneName:Teddm2;GeneType:protein_coding,
#   'ENSMUSG00000043282': GeneID:ENSMUSG00000043282;GeneName:Teddm1b;GeneType:protein_coding,
#   'ENSMUSG00000102459': GeneID:ENSMUSG00000102459;GeneName:Gm38352;GeneType:TEC,
#   'ENSMUSG00000047053': GeneID:ENSMUSG00000047053;GeneName:Teddm1a;GeneType:protein_coding,
#   'ENSMUSG00000099227': GeneID:ENSMUSG00000099227;GeneName:Mir8114;GeneType:miRNA,
#   'ENSMUSG00000026107': GeneID:ENSMUSG00000026107;GeneName:Nabp1;GeneType:protein_coding,
#   'ENSMUSG00000099413': GeneID:ENSMUSG00000099413;GeneName:Gm17767;GeneType:lncRNA,
#   'ENSMUSG00000103424': GeneID:ENSMUSG00000103424;GeneName:Gm37535;GeneType:TEC,
#   'ENSMUSG00000101741': GeneID:ENSMUSG00000101741;GeneName:Gm28055;GeneType:lncRNA,
#   'ENSMUSG00000054976': GeneID:ENSMUSG00000054976;GeneName:Nyap2;GeneType:protein_coding,
#   'ENSMUSG00000104029': GeneID:ENSMUSG00000104029;GeneName:Gm37210;GeneType:TEC,
#   'ENSMUSG00000101986': GeneID:ENSMUSG00000101986;GeneName:Gm6198;GeneType:processed_pseudogene,
#   'ENSMUSG00000087008': GeneID:ENSMUSG00000087008;GeneName:Gm5530;GeneType:processed_pseudogene,
#   'ENSMUSG00000100561': GeneID:ENSMUSG00000100561;GeneName:Gm7516;GeneType:processed_pseudogene,
#   'ENSMUSG00000103571': GeneID:ENSMUSG00000103571;GeneName:Gm37114;GeneType:TEC,
#   'ENSMUSG00000098797': GeneID:ENSMUSG00000098797;GeneName:Mir6344;GeneType:miRNA,
#   'ENSMUSG00000026473': GeneID:ENSMUSG00000026473;GeneName:Glul;GeneType:protein_coding,
#   'ENSMUSG00000100014': GeneID:ENSMUSG00000100014;GeneName:Gm29290;GeneType:lncRNA,
#   'ENSMUSG00000101903': GeneID:ENSMUSG00000101903;GeneName:Gm29291;GeneType:lncRNA,
#   'ENSMUSG00000055980': GeneID:ENSMUSG00000055980;GeneName:Irs1;GeneType:protein_coding,
#   'ENSMUSG00000100502': GeneID:ENSMUSG00000100502;GeneName:Gm28286;GeneType:lncRNA,
#   'ENSMUSG00000022591': GeneID:ENSMUSG00000022591;GeneName:Gm9747;GeneType:protein_coding,
#   'ENSMUSG00000100627': GeneID:ENSMUSG00000100627;GeneName:A830008E24Rik;GeneType:lncRNA,
#   'ENSMUSG00000088669': GeneID:ENSMUSG00000088669;GeneName:Gm25336;GeneType:snoRNA,
#   'ENSMUSG00000066797': GeneID:ENSMUSG00000066797;GeneName:Zfp648;GeneType:protein_coding,
#   'ENSMUSG00000048960': GeneID:ENSMUSG00000048960;GeneName:Prex2;GeneType:protein_coding,
#   'ENSMUSG00000099933': GeneID:ENSMUSG00000099933;GeneName:4930452N14Rik;GeneType:lncRNA,
#   'ENSMUSG00000100221': GeneID:ENSMUSG00000100221;GeneName:4930532M18Rik;GeneType:lncRNA,
#   'ENSMUSG00002076439': GeneID:ENSMUSG00002076439;GeneName:5S_rRNA;GeneType:rRNA,
#   'ENSMUSG00000100031': GeneID:ENSMUSG00000100031;GeneName:Gm18727;GeneType:processed_pseudogene,
#   'ENSMUSG00000077318': GeneID:ENSMUSG00000077318;GeneName:Gm24173;GeneType:snoRNA,
#   'ENSMUSG00000101827': GeneID:ENSMUSG00000101827;GeneName:Gm28686;GeneType:processed_pseudogene,
#   'ENSMUSG00000103494': GeneID:ENSMUSG00000103494;GeneName:Gm37410;GeneType:TEC,
#   'ENSMUSG00000026142': GeneID:ENSMUSG00000026142;GeneName:Rhbdd1;GeneType:protein_coding,
#   'ENSMUSG00000104493': GeneID:ENSMUSG00000104493;GeneName:Gm19552;GeneType:TEC,
#   'ENSMUSG00000100786': GeneID:ENSMUSG00000100786;GeneName:Gm28940;GeneType:lncRNA,
#   'ENSMUSG00002075724': GeneID:ENSMUSG00002075724;GeneName:ENSMUSG00002075724;GeneType:miRNA,
#   'ENSMUSG00000067158': GeneID:ENSMUSG00000067158;GeneName:Col4a4;GeneType:protein_coding,
#   'ENSMUSG00000079465': GeneID:ENSMUSG00000079465;GeneName:Col4a3;GeneType:protein_coding,
#   'ENSMUSG00002075966': GeneID:ENSMUSG00002075966;GeneName:5S_rRNA;GeneType:rRNA,
#   'ENSMUSG00000004110': GeneID:ENSMUSG00000004110;GeneName:Cacna1e;GeneType:protein_coding,
#   'ENSMUSG00000097564': GeneID:ENSMUSG00000097564;GeneName:C430014B12Rik;GeneType:lncRNA,
#   'ENSMUSG00000101880': GeneID:ENSMUSG00000101880;GeneName:Gm29282;GeneType:lncRNA,
#   'ENSMUSG00000101433': GeneID:ENSMUSG00000101433;GeneName:Gm29441;GeneType:processed_pseudogene,
#   'ENSMUSG00000096950': GeneID:ENSMUSG00000096950;GeneName:Gm9530;GeneType:lncRNA,
#   'ENSMUSG00000056708': GeneID:ENSMUSG00000056708;GeneName:Ier5;GeneType:protein_coding,
#   'ENSMUSG00000026471': GeneID:ENSMUSG00000026471;GeneName:Mr1;GeneType:protein_coding,
#   'ENSMUSG00000057715': GeneID:ENSMUSG00000057715;GeneName:A830018L16Rik;GeneType:protein_coding,
#   'ENSMUSG00000026470': GeneID:ENSMUSG00000026470;GeneName:Stx6;GeneType:protein_coding,
#   'ENSMUSG00000103825': GeneID:ENSMUSG00000103825;GeneName:Gm38178;GeneType:TEC,
#   'ENSMUSG00000099845': GeneID:ENSMUSG00000099845;GeneName:Gm29273;GeneType:processed_pseudogene,
#   'ENSMUSG00000103561': GeneID:ENSMUSG00000103561;GeneName:Gm38069;GeneType:TEC,
#   'ENSMUSG00000101610': GeneID:ENSMUSG00000101610;GeneName:Gm7560;GeneType:processed_pseudogene,
#   'ENSMUSG00000104181': GeneID:ENSMUSG00000104181;GeneName:Gm8850;GeneType:processed_pseudogene,
#   'ENSMUSG00000118923': GeneID:ENSMUSG00000118923;GeneName:U6;GeneType:snRNA,
#   'ENSMUSG00000098555': GeneID:ENSMUSG00000098555;GeneName:Mir6341;GeneType:miRNA,
#   'ENSMUSG00000097628': GeneID:ENSMUSG00000097628;GeneName:Gm2383;GeneType:processed_pseudogene,
#   'ENSMUSG00000098163': GeneID:ENSMUSG00000098163;GeneName:Gm6216;GeneType:processed_pseudogene,
#   'ENSMUSG00000097171': GeneID:ENSMUSG00000097171;GeneName:Gm17644;GeneType:lncRNA,
#   'ENSMUSG00000101314': GeneID:ENSMUSG00000101314;GeneName:Gm29663;GeneType:lncRNA,
#   'ENSMUSG00000033722': GeneID:ENSMUSG00000033722;GeneName:BC034090;GeneType:protein_coding,
#   'ENSMUSG00000103670': GeneID:ENSMUSG00000103670;GeneName:Gm37622;GeneType:lncRNA,
#   'ENSMUSG00000026150': GeneID:ENSMUSG00000026150;GeneName:Mff;GeneType:protein_coding,
#   'ENSMUSG00000101450': GeneID:ENSMUSG00000101450;GeneName:Gm28941;GeneType:lncRNA,
#   'ENSMUSG00000026149': GeneID:ENSMUSG00000026149;GeneName:Tm4sf20;GeneType:protein_coding,
#   'ENSMUSG00000114299': GeneID:ENSMUSG00000114299;GeneName:Gm47791;GeneType:protein_coding,
#   'ENSMUSG00000099771': GeneID:ENSMUSG00000099771;GeneName:Gm19257;GeneType:processed_pseudogene,
#   'ENSMUSG00000102280': GeneID:ENSMUSG00000102280;GeneName:Gm36999;GeneType:TEC,
#   'ENSMUSG00000100170': GeneID:ENSMUSG00000100170;GeneName:Gm28942;GeneType:lncRNA,
#   'ENSMUSG00000100744': GeneID:ENSMUSG00000100744;GeneName:Gm17764;GeneType:processed_pseudogene,
#   'ENSMUSG00002074851': GeneID:ENSMUSG00002074851;GeneName:ENSMUSG00002074851;GeneType:miRNA,
#   'ENSMUSG00000026469': GeneID:ENSMUSG00000026469;GeneName:Xpr1;GeneType:protein_coding,
#   'ENSMUSG00002076398': GeneID:ENSMUSG00002076398;GeneName:ENSMUSG00002076398;GeneType:miRNA,
#   'ENSMUSG00000073535': GeneID:ENSMUSG00000073535;GeneName:Gm5532;GeneType:lncRNA,
#   'ENSMUSG00000018417': GeneID:ENSMUSG00000018417;GeneName:Myo1b;GeneType:protein_coding,
#   'ENSMUSG00000101724': GeneID:ENSMUSG00000101724;GeneName:Gm29453;GeneType:lncRNA,
#   'ENSMUSG00000100313': GeneID:ENSMUSG00000100313;GeneName:Gm28323;GeneType:lncRNA,
#   'ENSMUSG00000100696': GeneID:ENSMUSG00000100696;GeneName:Gm8419;GeneType:processed_pseudogene,
#   'ENSMUSG00002075355': GeneID:ENSMUSG00002075355;GeneName:ENSMUSG00002075355;GeneType:snoRNA,
#   'ENSMUSG00000072324': GeneID:ENSMUSG00000072324;GeneName:Gm8420;GeneType:processed_pseudogene,
#   'ENSMUSG00000026490': GeneID:ENSMUSG00000026490;GeneName:Cdc42bpa;GeneType:protein_coding,
#   'ENSMUSG00000033701': GeneID:ENSMUSG00000033701;GeneName:Acbd6;GeneType:protein_coding,
#   'ENSMUSG00000102194': GeneID:ENSMUSG00000102194;GeneName:Gm38169;GeneType:TEC,
#   'ENSMUSG00000103636': GeneID:ENSMUSG00000103636;GeneName:Gm38331;GeneType:TEC,
# ...
#   'ENSMUST00000185210': TranscriptID:ENSMUST00000185210;TranscriptType:processed_pseudogene,
#   'ENSMUST00000186233': TranscriptID:ENSMUST00000186233;TranscriptType:processed_pseudogene,
#   'ENSMUST00000190006': TranscriptID:ENSMUST00000190006;TranscriptType:lncRNA,
#   'ENSMUST00000121202': TranscriptID:ENSMUST00000121202;TranscriptType:processed_pseudogene,
#   'ENSMUST00000195733': TranscriptID:ENSMUST00000195733;TranscriptType:TEC,
#   'ENSMUST00000183639': TranscriptID:ENSMUST00000183639;TranscriptType:miRNA,
#   'ENSMUST00000187720': TranscriptID:ENSMUST00000187720;TranscriptType:processed_pseudogene,
#   'ENSMUST00000194762': TranscriptID:ENSMUST00000194762;TranscriptType:TEC,
#   'ENSMUST00000187358': TranscriptID:ENSMUST00000187358;TranscriptType:processed_pseudogene,
#   'ENSMUST00020183648': TranscriptID:ENSMUST00020183648;TranscriptType:miRNA,
#   'ENSMUST00020181689': TranscriptID:ENSMUST00020181689;TranscriptType:misc_RNA,
#   'ENSMUST00000186401': TranscriptID:ENSMUST00000186401;TranscriptType:processed_pseudogene,
#   'ENSMUST00000181607': TranscriptID:ENSMUST00000181607;TranscriptType:processed_pseudogene,
#   'ENSMUST00000083009': TranscriptID:ENSMUST00000083009;TranscriptType:snRNA,
#   'ENSMUST00000188192': TranscriptID:ENSMUST00000188192;TranscriptType:processed_pseudogene,
#   'ENSMUST00000189223': TranscriptID:ENSMUST00000189223;TranscriptType:processed_pseudogene,
#   'ENSMUST00000191041': TranscriptID:ENSMUST00000191041;TranscriptType:processed_pseudogene,
#   'ENSMUST00000181115': TranscriptID:ENSMUST00000181115;TranscriptType:processed_pseudogene,
#   'ENSMUST00020182092': TranscriptID:ENSMUST00020182092;TranscriptType:miRNA,
#   'ENSMUST00000186142': TranscriptID:ENSMUST00000186142;TranscriptType:processed_pseudogene,
#   'ENSMUST00000190610': TranscriptID:ENSMUST00000190610;TranscriptType:retained_intron,
#   'ENSMUST00000191012': TranscriptID:ENSMUST00000191012;TranscriptType:protein_coding,
#   'ENSMUST00000071087': TranscriptID:ENSMUST00000071087;TranscriptType:protein_coding,
#   'ENSMUST00000143606': TranscriptID:ENSMUST00000143606;TranscriptType:retained_intron,
#   'ENSMUST00000191360': TranscriptID:ENSMUST00000191360;TranscriptType:retained_intron,
#   'ENSMUST00000117415': TranscriptID:ENSMUST00000117415;TranscriptType:protein_coding,
#   'ENSMUST00000191521': TranscriptID:ENSMUST00000191521;TranscriptType:retained_intron,
#   'ENSMUST00000118263': TranscriptID:ENSMUST00000118263;TranscriptType:protein_coding,
#   'ENSMUST00000122156': TranscriptID:ENSMUST00000122156;TranscriptType:protein_coding,
#   'ENSMUST00000190063': TranscriptID:ENSMUST00000190063;TranscriptType:retained_intron,
#   'ENSMUST00000119714': TranscriptID:ENSMUST00000119714;TranscriptType:protein_coding,
#   'ENSMUST00000134716': TranscriptID:ENSMUST00000134716;TranscriptType:retained_intron,
#   'ENSMUST00000155974': TranscriptID:ENSMUST00000155974;TranscriptType:protein_coding,
#   'ENSMUST00000186294': TranscriptID:ENSMUST00000186294;TranscriptType:protein_coding,
#   'ENSMUST00000149214': TranscriptID:ENSMUST00000149214;TranscriptType:protein_coding,
#   'ENSMUST00000190318': TranscriptID:ENSMUST00000190318;TranscriptType:retained_intron,
#   'ENSMUST00000188249': TranscriptID:ENSMUST00000188249;TranscriptType:retained_intron,
#   'ENSMUST00000153804': TranscriptID:ENSMUST00000153804;TranscriptType:retained_intron,
#   'ENSMUST00000188449': TranscriptID:ENSMUST00000188449;TranscriptType:nonsense_mediated_decay,
#   'ENSMUST00000123261': TranscriptID:ENSMUST00000123261;TranscriptType:retained_intron,
#   'ENSMUST00000185422': TranscriptID:ENSMUST00000185422;TranscriptType:retained_intron,
#   'ENSMUST00000190625': TranscriptID:ENSMUST00000190625;TranscriptType:retained_intron,
#   'ENSMUST00000187226': TranscriptID:ENSMUST00000187226;TranscriptType:nonsense_mediated_decay,
#   'ENSMUST00000136283': TranscriptID:ENSMUST00000136283;TranscriptType:retained_intron,
#   'ENSMUST00000128164': TranscriptID:ENSMUST00000128164;TranscriptType:retained_intron,
#   'ENSMUST00000136898': TranscriptID:ENSMUST00000136898;TranscriptType:retained_intron,
#   'ENSMUST00000148663': TranscriptID:ENSMUST00000148663;TranscriptType:retained_intron,
#   'ENSMUST00000186145': TranscriptID:ENSMUST00000186145;TranscriptType:processed_pseudogene,
#   'ENSMUST00000188673': TranscriptID:ENSMUST00000188673;TranscriptType:lncRNA,
#   'ENSMUST00000056879': TranscriptID:ENSMUST00000056879;TranscriptType:lncRNA,
#   'ENSMUST00000189810': TranscriptID:ENSMUST00000189810;TranscriptType:processed_pseudogene,
#   'ENSMUST00000185858': TranscriptID:ENSMUST00000185858;TranscriptType:processed_pseudogene,
#   'ENSMUST00000186262': TranscriptID:ENSMUST00000186262;TranscriptType:processed_pseudogene,
#   'ENSMUST00000190905': TranscriptID:ENSMUST00000190905;TranscriptType:processed_pseudogene,
#   'ENSMUST00000194474': TranscriptID:ENSMUST00000194474;TranscriptType:TEC,
#   'ENSMUST00000186016': TranscriptID:ENSMUST00000186016;TranscriptType:lncRNA,
#   'ENSMUST00000185632': TranscriptID:ENSMUST00000185632;TranscriptType:processed_pseudogene,
#   'ENSMUST00020183189': TranscriptID:ENSMUST00020183189;TranscriptType:misc_RNA,
#   'ENSMUST00000191457': TranscriptID:ENSMUST00000191457;TranscriptType:lncRNA,
#   'ENSMUST00000187207': TranscriptID:ENSMUST00000187207;TranscriptType:processed_pseudogene,
#   'ENSMUST00020182001': TranscriptID:ENSMUST00020182001;TranscriptType:misc_RNA,
#   'ENSMUST00000187677': TranscriptID:ENSMUST00000187677;TranscriptType:lncRNA,
#   'ENSMUST00000041776': TranscriptID:ENSMUST00000041776;TranscriptType:protein_coding,
#   'ENSMUST00000124500': TranscriptID:ENSMUST00000124500;TranscriptType:protein_coding,
#   'ENSMUST00000111815': TranscriptID:ENSMUST00000111815;TranscriptType:protein_coding,
#   'ENSMUST00000152114': TranscriptID:ENSMUST00000152114;TranscriptType:protein_coding,
#   'ENSMUST00000111812': TranscriptID:ENSMUST00000111812;TranscriptType:protein_coding,
#   'ENSMUST00000147700': TranscriptID:ENSMUST00000147700;TranscriptType:protein_coding,
#   'ENSMUST00000147482': TranscriptID:ENSMUST00000147482;TranscriptType:protein_coding,
#   'ENSMUST00000111814': TranscriptID:ENSMUST00000111814;TranscriptType:protein_coding,
#   'ENSMUST00000111810': TranscriptID:ENSMUST00000111810;TranscriptType:protein_coding,
#   'ENSMUST00000147794': TranscriptID:ENSMUST00000147794;TranscriptType:processed_transcript,
#   'ENSMUST00000187154': TranscriptID:ENSMUST00000187154;TranscriptType:lncRNA,
#   'ENSMUST00000193511': TranscriptID:ENSMUST00000193511;TranscriptType:TEC,
#   'ENSMUST00000190663': TranscriptID:ENSMUST00000190663;TranscriptType:lncRNA,
#   'ENSMUST00000186103': TranscriptID:ENSMUST00000186103;TranscriptType:processed_transcript,
#   'ENSMUST00000139157': TranscriptID:ENSMUST00000139157;TranscriptType:processed_transcript,
#   'ENSMUST00000114565': TranscriptID:ENSMUST00000114565;TranscriptType:protein_coding,
#   'ENSMUST00000081851': TranscriptID:ENSMUST00000081851;TranscriptType:protein_coding,
#   'ENSMUST00000027748': TranscriptID:ENSMUST00000027748;TranscriptType:protein_coding,
#   'ENSMUST00000191474': TranscriptID:ENSMUST00000191474;TranscriptType:lncRNA,
#   'ENSMUST00000185627': TranscriptID:ENSMUST00000185627;TranscriptType:lncRNA,
#   'ENSMUST00020182029': TranscriptID:ENSMUST00020182029;TranscriptType:miRNA,
#   'ENSMUST00000189560': TranscriptID:ENSMUST00000189560;TranscriptType:lncRNA,
#   'ENSMUST00000187777': TranscriptID:ENSMUST00000187777;TranscriptType:lncRNA,
#   'ENSMUST00000190705': TranscriptID:ENSMUST00000190705;TranscriptType:lncRNA,
#   'ENSMUST00000189867': TranscriptID:ENSMUST00000189867;TranscriptType:lncRNA,
#   'ENSMUST00000051572': TranscriptID:ENSMUST00000051572;TranscriptType:protein_coding,
#   'ENSMUST00000187104': TranscriptID:ENSMUST00000187104;TranscriptType:processed_pseudogene,
#   'ENSMUST00000189460': TranscriptID:ENSMUST00000189460;TranscriptType:lncRNA,
#   'ENSMUST00000086209': TranscriptID:ENSMUST00000086209;TranscriptType:protein_coding,
#   'ENSMUST00000182722': TranscriptID:ENSMUST00000182722;TranscriptType:protein_coding,
#   'ENSMUST00000183241': TranscriptID:ENSMUST00000183241;TranscriptType:protein_coding,
#   'ENSMUST00000182131': TranscriptID:ENSMUST00000182131;TranscriptType:retained_intron,
#   'ENSMUST00000182538': TranscriptID:ENSMUST00000182538;TranscriptType:protein_coding,
#   'ENSMUST00000182016': TranscriptID:ENSMUST00000182016;TranscriptType:processed_transcript,
#   'ENSMUST00000187415': TranscriptID:ENSMUST00000187415;TranscriptType:lncRNA,
#   'ENSMUST00000088615': TranscriptID:ENSMUST00000088615;TranscriptType:protein_coding,
#   'ENSMUST00000187417': TranscriptID:ENSMUST00000187417;TranscriptType:retained_intron,
#   'ENSMUST00000142497': TranscriptID:ENSMUST00000142497;TranscriptType:retained_intron,
#   'ENSMUST00000156563': TranscriptID:ENSMUST00000156563;TranscriptType:retained_intron,
#   'ENSMUST00000128834': TranscriptID:ENSMUST00000128834;TranscriptType:retained_intron,
#   'ENSMUST00000131556': TranscriptID:ENSMUST00000131556;TranscriptType:protein_coding,
#   'ENSMUST00000186813': TranscriptID:ENSMUST00000186813;TranscriptType:retained_intron,
#   'ENSMUST00000186720': TranscriptID:ENSMUST00000186720;TranscriptType:retained_intron,
#   'ENSMUST00020183640': TranscriptID:ENSMUST00020183640;TranscriptType:misc_RNA,
#   'ENSMUST00000192111': TranscriptID:ENSMUST00000192111;TranscriptType:TEC,
#   'ENSMUST00000077946': TranscriptID:ENSMUST00000077946;TranscriptType:protein_coding,
#   'ENSMUST00000190595': TranscriptID:ENSMUST00000190595;TranscriptType:protein_coding,
#   'ENSMUST00000187774': TranscriptID:ENSMUST00000187774;TranscriptType:protein_coding,
#   'ENSMUST00000189486': TranscriptID:ENSMUST00000189486;TranscriptType:protein_coding,
#   'ENSMUST00000190983': TranscriptID:ENSMUST00000190983;TranscriptType:protein_coding,
#   'ENSMUST00000186835': TranscriptID:ENSMUST00000186835;TranscriptType:retained_intron,
#   'ENSMUST00000187885': TranscriptID:ENSMUST00000187885;TranscriptType:retained_intron,
#   'ENSMUST00000191505': TranscriptID:ENSMUST00000191505;TranscriptType:retained_intron,
#   'ENSMUST00000186087': TranscriptID:ENSMUST00000186087;TranscriptType:protein_coding,
#   'ENSMUST00000191449': TranscriptID:ENSMUST00000191449;TranscriptType:protein_coding,
#   'ENSMUST00000187698': TranscriptID:ENSMUST00000187698;TranscriptType:retained_intron,
#   'ENSMUST00000153695': TranscriptID:ENSMUST00000153695;TranscriptType:nonsense_mediated_decay,
#   'ENSMUST00000035577': TranscriptID:ENSMUST00000035577;TranscriptType:protein_coding,
#   'ENSMUST00000147575': TranscriptID:ENSMUST00000147575;TranscriptType:retained_intron,
#   'ENSMUST00000140938': TranscriptID:ENSMUST00000140938;TranscriptType:processed_transcript,
#   'ENSMUST00000194845': TranscriptID:ENSMUST00000194845;TranscriptType:TEC,
#   'ENSMUST00000118350': TranscriptID:ENSMUST00000118350;TranscriptType:processed_pseudogene,
#   'ENSMUST00000240462': TranscriptID:ENSMUST00000240462;TranscriptType:snRNA,
#   'ENSMUST00000141249': TranscriptID:ENSMUST00000141249;TranscriptType:protein_coding,
#   'ENSMUST00000238926': TranscriptID:ENSMUST00000238926;TranscriptType:protein_coding,
#   'ENSMUST00000124558': TranscriptID:ENSMUST00000124558;TranscriptType:protein_coding,
#   'ENSMUST00000184095': TranscriptID:ENSMUST00000184095;TranscriptType:nonsense_mediated_decay,
#   'ENSMUST00000145308': TranscriptID:ENSMUST00000145308;TranscriptType:processed_transcript,
#   'ENSMUST00000185164': TranscriptID:ENSMUST00000185164;TranscriptType:nonsense_mediated_decay,
#   'ENSMUST00000134030': TranscriptID:ENSMUST00000134030;TranscriptType:retained_intron,
#   'ENSMUST00000206321': TranscriptID:ENSMUST00000206321;TranscriptType:processed_transcript,
#   'ENSMUST00000119252': TranscriptID:ENSMUST00000119252;TranscriptType:processed_pseudogene,
#   'ENSMUST00000192705': TranscriptID:ENSMUST00000192705;TranscriptType:TEC,
#   'ENSMUST00000194285': TranscriptID:ENSMUST00000194285;TranscriptType:TEC,
#   'ENSMUST00000192541': TranscriptID:ENSMUST00000192541;TranscriptType:TEC,
#   'ENSMUST00000189483': TranscriptID:ENSMUST00000189483;TranscriptType:processed_pseudogene,
#   'ENSMUST00000195842': TranscriptID:ENSMUST00000195842;TranscriptType:TEC,
#   'ENSMUST00000188013': TranscriptID:ENSMUST00000188013;TranscriptType:processed_pseudogene,
#   'ENSMUST00020182331': TranscriptID:ENSMUST00020182331;TranscriptType:snoRNA,
#   'ENSMUST00000186576': TranscriptID:ENSMUST00000186576;TranscriptType:processed_pseudogene,
#   'ENSMUST00000188657': TranscriptID:ENSMUST00000188657;TranscriptType:processed_pseudogene,
#   'ENSMUST00000059607': TranscriptID:ENSMUST00000059607;TranscriptType:protein_coding,
#   'ENSMUST00000123490': TranscriptID:ENSMUST00000123490;TranscriptType:protein_coding,
#   'ENSMUST00000190620': TranscriptID:ENSMUST00000190620;TranscriptType:retained_intron,
#   'ENSMUST00000055314': TranscriptID:ENSMUST00000055314;TranscriptType:protein_coding,
#   'ENSMUST00000194459': TranscriptID:ENSMUST00000194459;TranscriptType:TEC,
#   'ENSMUST00000050660': TranscriptID:ENSMUST00000050660;TranscriptType:protein_coding,
#   'ENSMUST00000183582': TranscriptID:ENSMUST00000183582;TranscriptType:miRNA,
#   'ENSMUST00000189542': TranscriptID:ENSMUST00000189542;TranscriptType:nonsense_mediated_decay,
#   'ENSMUST00000186003': TranscriptID:ENSMUST00000186003;TranscriptType:nonsense_mediated_decay,
#   'ENSMUST00000190103': TranscriptID:ENSMUST00000190103;TranscriptType:nonsense_mediated_decay,
#   'ENSMUST00000027279': TranscriptID:ENSMUST00000027279;TranscriptType:protein_coding,
#   'ENSMUST00000186684': TranscriptID:ENSMUST00000186684;TranscriptType:protein_coding,
#   'ENSMUST00000188204': TranscriptID:ENSMUST00000188204;TranscriptType:protein_coding,
#   'ENSMUST00000188051': TranscriptID:ENSMUST00000188051;TranscriptType:protein_coding,
#   'ENSMUST00000185534': TranscriptID:ENSMUST00000185534;TranscriptType:protein_coding,
#   'ENSMUST00000185961': TranscriptID:ENSMUST00000185961;TranscriptType:retained_intron,
#   'ENSMUST00000188303': TranscriptID:ENSMUST00000188303;TranscriptType:retained_intron,
#   'ENSMUST00000190169': TranscriptID:ENSMUST00000190169;TranscriptType:lncRNA,
#   'ENSMUST00000189410': TranscriptID:ENSMUST00000189410;TranscriptType:lncRNA,
#   'ENSMUST00000194442': TranscriptID:ENSMUST00000194442;TranscriptType:TEC,
#   'ENSMUST00000189576': TranscriptID:ENSMUST00000189576;TranscriptType:lncRNA,
#   'ENSMUST00000186769': TranscriptID:ENSMUST00000186769;TranscriptType:lncRNA,
#   'ENSMUST00000137862': TranscriptID:ENSMUST00000137862;TranscriptType:protein_coding,
#   'ENSMUST00000123720': TranscriptID:ENSMUST00000123720;TranscriptType:protein_coding,
#   'ENSMUST00000068275': TranscriptID:ENSMUST00000068275;TranscriptType:protein_coding,
#   'ENSMUST00000113494': TranscriptID:ENSMUST00000113494;TranscriptType:protein_coding,
#   'ENSMUST00000123285': TranscriptID:ENSMUST00000123285;TranscriptType:protein_coding,
#   'ENSMUST00000192484': TranscriptID:ENSMUST00000192484;TranscriptType:TEC,
#   'ENSMUST00000191337': TranscriptID:ENSMUST00000191337;TranscriptType:processed_pseudogene,
#   'ENSMUST00000117185': TranscriptID:ENSMUST00000117185;TranscriptType:processed_pseudogene,
#   'ENSMUST00000186198': TranscriptID:ENSMUST00000186198;TranscriptType:processed_pseudogene,
#   'ENSMUST00000195065': TranscriptID:ENSMUST00000195065;TranscriptType:TEC,
#   'ENSMUST00000183462': TranscriptID:ENSMUST00000183462;TranscriptType:miRNA,
#   'ENSMUST00000086199': TranscriptID:ENSMUST00000086199;TranscriptType:protein_coding,
#   'ENSMUST00000140685': TranscriptID:ENSMUST00000140685;TranscriptType:protein_coding,
#   'ENSMUST00000139476': TranscriptID:ENSMUST00000139476;TranscriptType:protein_coding,
#   'ENSMUST00000153134': TranscriptID:ENSMUST00000153134;TranscriptType:processed_transcript,
#   'ENSMUST00000154576': TranscriptID:ENSMUST00000154576;TranscriptType:retained_intron,
#   'ENSMUST00000185385': TranscriptID:ENSMUST00000185385;TranscriptType:lncRNA,
#   'ENSMUST00000188927': TranscriptID:ENSMUST00000188927;TranscriptType:lncRNA,
#   'ENSMUST00000186055': TranscriptID:ENSMUST00000186055;TranscriptType:lncRNA,
#   'ENSMUST00000069799': TranscriptID:ENSMUST00000069799;TranscriptType:protein_coding,
#   ...})

# %%
from collections import Counter,defaultdict
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import numpy as np
import pysam
from matplotlib.backends.backend_pdf import PdfPages
#from prepare_transcripts import *
#from .detectORF import extract_frame,test_frame
#from .parsing_opts import parsing_metaplots
import os
import sys

# %%
import pyfasta
import RiboMiner

# %%
import pandas as pd
import numpy as np

print('\n'.join(f'{m.__name__}=={m.__version__}' for m in globals().values() if getattr(m, '__version__', None)))
# Out:
# re==2.2.1
# argparse==1.1
# matplotlib==3.3.4
# numpy==1.22.3
# pysam==0.16.0.1
# h5py==2.10.0
# pandas==1.2.4

# %%
# Out:
# Traceback (most recent call last):
#   File "/home/nmishra/.conda/envs/RiboMiner/bin/metaplots", line 33, in <module>
#     sys.exit(load_entry_point('RiboCode==1.2.15', 'console_scripts', 'metaplots')())
#   File "/home/nmishra/.conda/envs/RiboMiner/bin/metaplots", line 25, in importlib_load_entry_point
#     return next(matches).load()
#   File "/home/nmishra/.conda/envs/RiboMiner/lib/python3.7/site-packages/importlib_metadata/__init__.py", line 209, in load
#     module = import_module(match.group('module'))
#   File "/home/nmishra/.conda/envs/RiboMiner/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 677, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 728, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/nmishra/.conda/envs/RiboMiner/lib/python3.7/site-packages/RiboCode/metaplots.py", line 16, in <module>
#     from .prepare_transcripts import *
#   File "/home/nmishra/.conda/envs/RiboMiner/lib/python3.7/site-packages/RiboCode/prepare_transcripts.py", line 17, in <module>
#     from pyfasta import Fasta
#   File "/home/nmishra/.conda/envs/RiboMiner/lib/python3.7/site-packages/pyfasta/__init__.py", line 4, in <module>
#     from pyfasta import DuplicateHeaderException
# ImportError: cannot import name 'DuplicateHeaderException' from 'pyfasta' (/home/nmishra/.conda/envs/RiboMiner/lib/python3.7/site-packages/pyfasta/__init__.py)
